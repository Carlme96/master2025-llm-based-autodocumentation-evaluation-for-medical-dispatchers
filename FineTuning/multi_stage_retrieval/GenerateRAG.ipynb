# %%
import os
import re
import uuid
import json
import numpy as np
from typing import List
from copy import deepcopy
from dotenv import load_dotenv
import matplotlib.pyplot as plt
from pathlib import Path
from collections import defaultdict
from langchain.prompts import ChatPromptTemplate, PromptTemplate
from typing import Optional, Any, defaultdict
from langchain.chat_models import init_chat_model
from pydantic import BaseModel, Field, field_validator
from langchain.output_parsers import PydanticOutputParser
from pydantic_settings import BaseSettings, SettingsConfigDict
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser

# %%
def load_env():
	env_file_path = ".env"
	if os.path.exists(env_file_path):
		load_dotenv(env_file_path, override=True)
		print("Loaded environment variables")
	else:
		print(f"Error: .env file not found at {env_file_path}")

load_env()

class ModelSettings(BaseSettings):
	model: str
	temperature: Optional[float] = 0
	max_tokens: Optional[int] = None

class ProcessModelSettings(BaseSettings):
	gpt41: ModelSettings
	gpt4o_mini: ModelSettings
	gpt41_mini: ModelSettings
	o1_mini: ModelSettings
	gpt41_nano: ModelSettings
	deepseek: ModelSettings
	phi4: ModelSettings
	embedding: ModelSettings


class Settings(BaseSettings):
	model_config = SettingsConfigDict(env_file=".env", env_nested_delimiter="__")

	# Keys
	azure_openai_api_key: Optional[str]
	azure_openai_endpoint: Optional[str]
	openai_api_version: Optional[str]

	openai_api_deployment_name_gpt4_vision_no_filters: Optional[str]
	openai_vision_api_version_gpt4_vision_no_filters: Optional[str]
	openai_api_key_gpt4_vision_no_filters: Optional[str]
	openai_base_url_gpt4_vision_no_filters: Optional[str]

	# models
	processmodel: ProcessModelSettings


settings = Settings()
# Out:
# Loaded environment variables

# %% [markdown]
# Define which documents to process

# %%
start_index = 2
end_index = -3
exclude = np.array([21])
exclude-=1

# %%
def extract_chapter_title(content):
	pattern = r"^#\s*(.+)$"
	for i, line in enumerate(content.split("\n"), start=1):
		match = re.match(pattern, line)
		if match:
			return match.group(1).strip()
	return ""

# %%
file_paths = ["Data/LabelWork/" + file for file in os.listdir("Data/LabelWork")]
file_paths.sort()

# Resolve end index if negative
resolved_end = len(file_paths) + end_index if end_index < 0 else end_index
indices = [i for i in range(start_index, resolved_end) if i not in exclude.tolist()]
file_paths = [file_paths[i] for i in indices]

Chapters = []
ChapterContent = {}
Content = {}
for file_path in file_paths:
	chapter_text = Path(file_path).read_text(encoding="utf-8")
	chapter = extract_chapter_title(chapter_text).strip()
	Content[chapter] = chapter_text
	Chapters.append(chapter)
	ChapterContent[chapter] = chapter_text


chapter_str = "\n- " + "\n- ".join(Chapters)
print(chapter_str)
# Out:
# - 03 Unconscious / decreased level of consciousness, breathing normally
# - 04 Choking / foreign object
# - 05 Mental health issue
# - 06 Mental health crisis - suicide risk
# - 07 Burns
# - 08 Drowning
# - 09 Scuba diving accident
# - 10 Chemicals / gasses / CBRN
# - 11 Accident / injury
# - 12 Major incident
# - 13 Road traffic accident - RTA
# - 14 Violence / abuse
# - 15 Allergic reaction
# - 16 Child / infant - illness
# - 17 Bite / insect sting
# - 18 Bleeding - non-traumatic
# - 19 Chest pain / cardiac disease
# - 20 Diabetes
# - 22 Fever / infection / sepsis
# - 23 Poisoning - not related to alcohol or drugs
# - 24 Functional decline
# - 25 Childbirth
# - 26 Gynecology / pregnancy
# - 27 Stroke symptoms
# - 28 Headache
# - 29 Skin / rash
# - 30 Hyperthermia / heat stroke / heat exhaustion
# - 31 Hypothermia / cold person
# - 32 Seizures (convulsions, fits)
# - 33 Breathing problems
# - 34 Drug abuse / intoxication / overdose
# - 35 Pain in the abdomen / back / extremities
# - 36 Uncertain / unidentified problem
# - 37 Urinary tract
# - 38 Ear, nose and throat
# - 39 Eye

# %%
summarize_template = PromptTemplate(
    template="""
You are a summarization assistant for a medical retrieval (RAG) system, tasked with producing one focused paragraph per chapter.

You are given:
- A “document” mixing relevant material for one chapter with unrelated or overlapping content.
- A “chapter_list” of all other chapters (to avoid overlap).

Here is the list of other chapters (do not include any of their content):  
{chapter_list}

Here is the source document:  
{document}

# Instructions  
1. Only include signs, symptoms, observations, causes, or clinical features that are uniquely and exclusively related to the target chapter.  
2. Do not include anything that conceptually, terminologically, or contextually fits any other chapter. Avoid general or overlapping criteria.  
3. Exclude any procedural, treatment, or management details. Focus solely on defining clinical features.  
4. Avoid restating or paraphrasing content that can belong to other chapters, even if it appears in the source document.  
5. Write a clear, professional, self-contained paragraph. Include concrete examples of the chapter's defining symptoms or scenarios.  

Important:  
- This summary will feed into an embedding-based search system; precision and exclusivity are critical.  
- Strictly avoid any conceptual or terminological overlap with other chapters.

# Output:
""",
    input_variables=["chapter_list", "document"],
)



short_summary_template = PromptTemplate(
    template="""
You are a summarization assistant for a medical retrieval (RAG) system. Your task is to generate a **strictly isolated, short summary** based **only on the provided document**, focusing on **chapter-specific clinical criteria**.

You are given:
- A “document” with content related to one medical chapter, mixed with potential overlaps.
- A “chapter_list” of other chapters to avoid conceptually or terminologically.

## source document:
{document}
---

## chapter_list (do not include or hint at these):
{chapter_list}
---

# Instructions  
1. Identify only the signs, symptoms, causes, or observable criteria that are **exclusively** tied to this chapter.
2. Do **not** include any clinical features, terms, or observations that may also belong to the chapters in `chapter_list`.  
3. Avoid procedural, treatment-related, or diagnostic advice. Focus **only** on defining features.  
4. If you are unsure whether something is exclusive to this chapter, leave it out. Prioritize precision by excluding anything that could possibly relate to other chapters.
5. The summary must be **factual, concise (max 50 words)**, and **self-contained**.  
6. **Use only the source document. Do not use external knowledge.**
7. Write the summary in key-word format, avoiding any markdown or formatting symbols

# Write the output as a single paragraph with exactly 50 words:
""",
    input_variables=["chapter_list", "document"],
)



filter_criteria_template = PromptTemplate(
    template="""
You are a medical assistant helping to curate a clean, non-overlapping list of clinical criteria for a retrieval system.

You are given:
- A list of "criteria" that may contain noise or ambiguity.
- A list of "other chapters" representing distinct medical topics to avoid.

Your task is to:
1. Identify which criteria are clearly relevant only to the intended topic.
2. Exclude any criteria that overlap conceptually, terminologically, or contextually with any of the chapters in the list.
3. Return only the clean, chapter-specific criteria — without modification or rephrasing.

# List of other chapters (to avoid):
{chapter_list}

# Input criteria:
{criteria_list}

# Output: Return a list of criteria that do NOT overlap with other chapters.
Respond only with a clean list of the accepted criteria:
""",
    input_variables=["criteria_list", "chapter_list"],
)




def call_llm_template(template, input_data):

	try:
		llm = init_chat_model(**settings.processmodel.gpt41.model_dump(exclude_none=True))
		chain = template | llm | StrOutputParser()
		return chain.invoke(input_data)
	except Exception as e:
		print(f"Error calling LLM: {e}")
	
	
	print("- Warning: Retrying with gpt4o-mini...")
	try:
		llm = init_chat_model(**settings.processmodel.gpt4o_mini.model_dump(exclude_none=True))
		chain = template | llm | StrOutputParser()
		return chain.invoke(input_data)
	except Exception as e:
		print(f"Error calling LLM: {e}")


	print("- Warning: Retrying with gpt41-mini...")
	try:
		llm = init_chat_model(**settings.processmodel.gpt41_mini.model_dump(exclude_none=True))
		chain = template | llm | StrOutputParser()
		return chain.invoke(input_data)
	except Exception as e:
		print(f"Error calling LLM: {e}")
	

	print("- Warning: Retrying with o1_mini...")
	try:
		llm = init_chat_model(**settings.processmodel.o1_mini.model_dump(exclude_none=True))
		chain = template | llm | StrOutputParser()
		return chain.invoke(input_data)
	except Exception as e:
		print(f"Error calling LLM: {e}")
	
	print("- Warning: Retrying with gpt41_nano...")
	try:
		llm = init_chat_model(**settings.processmodel.gpt41_nano.model_dump(exclude_none=True))
		chain = template | llm | StrOutputParser()
		return chain.invoke(input_data)
	except Exception as e:
		print(f"Error calling LLM: {e}")
	

	print("- Warning: Retrying with deepseek model...")
	try:
		llm = init_chat_model(**settings.processmodel.deepseek.model_dump(exclude_none=True))
		chain = template | llm | StrOutputParser()
		cot_response = chain.invoke(input_data)
		response =  re.sub(r"<think>.*?</think>", "", cot_response, flags=re.DOTALL).strip()
		return response.strip()
	except Exception as e:
		print(f"Error calling LLM: {e}")
		
	
	display("- Warning: FAILED to generate criteria for empty categories.")

def retry_llm_generation(template, input_data):
	response = None
	while True:
		response = call_llm_template(template, input_data)
		if not response:
			print("Error: None response from the model")
			continue

		response = response.strip().replace("\n\n", "\n")
		words = len(response.split(" "))
		print(f"Response length: {words} words")
		if words < 40 or words > 50:
			print(f"Warning: Response length {words} is outside the expected range (40-50). Retrying...")
			continue

		break
	
		
	return response

# %%
from collections import defaultdict

def longest_common_word_prefix(a, b):
	a_words = a.split()
	b_words = b.split()
	min_len = min(len(a_words), len(b_words))
	prefix_words = []
	for i in range(min_len):
		if a_words[i] == b_words[i]:
			prefix_words.append(a_words[i])
		else:
			break
	return ' '.join(prefix_words)


def format_text(criteria_list):

	# Step 1: Find common word prefixes between all pairs
	prefix_counter = defaultdict(set)

	for i, c1 in enumerate(criteria_list):
		for j in range(i+1, len(criteria_list)):
			c2 = criteria_list[j]
			prefix = longest_common_word_prefix(c1, c2)
			if len(prefix.split()) >= 3:  # threshold to avoid noise
				prefix_counter[prefix].add(c1)
				prefix_counter[prefix].add(c2)

	# Step 2: Keep only those used by 2+ unique lines
	valid_prefixes = {p for p, v in prefix_counter.items() if len(v) >= 2}

	# Step 3: Remove shorter prefixes that are sub-prefixes of longer ones
	final_prefixes = []
	for p in sorted(valid_prefixes, key=lambda x: -len(x)):
		if not any(p != other and p.startswith(other) for other in final_prefixes):
			final_prefixes.append(p)

	# Step 4: Group lines
	grouped = defaultdict(list)

	for line in criteria_list:
		matched = False
		for prefix in final_prefixes:
			if line.startswith(prefix):
				grouped[prefix].append(line[len(prefix):].lstrip(" :"))
				matched = True
				break
		if not matched:
			grouped["Other"].append(line)

	prefix = "" #"This chapter is relevant when the patient shows one or more of these symptoms:\n\n"

	# Step 5: Print
	result = ""
	for group, items in grouped.items():
		if group != "Other":
			result += f"\n\n{group}"
		for item in items:
			if item.strip() != "":
				result += f"\n- {item}"
	return prefix + result.strip()

def extract_sections_list(content):
	pattern = r'(^## (?!#).*?(?=^## (?!#)|\Z))'
	sections = re.findall(pattern, content, flags=re.MULTILINE | re.DOTALL)
	section_list = []
	for sec in sections:
		sec = sec.strip()
		lines = sec.splitlines()
		if lines:
			header = lines[0][3:].strip()  # Remove "## " prefix
			body = "\n".join(lines[1:]).strip()
			section_list.append((header, body))  # Store as a tuple
	return section_list

def get_criteria(text):
	criteria_pattern = r"^-\s*(Critical|Urgent|Normal)\s*\|\s*([^|\n]+)(?:\|\s*([^|\n]+))?$"
	matches = re.findall(criteria_pattern, text, flags=re.MULTILINE)
	criteria_list = []
	for _, criteria, _ in matches:
		criteria = criteria.strip()
		# Remove useless criteria/advices
		if "other, not urgent" in criteria.lower() or "other symptoms related to this page" in criteria.lower():
			continue
		criteria_list.append(criteria.strip())
	return criteria_list


def get_scenario(text):
	scenario_match = re.search(r"### SCENARIO\s*(.*?)(?=\n###|\n##|\n#|$)", text, re.DOTALL)
	scenario_content = scenario_match.group(1).strip() if scenario_match else None
	scenario_content = scenario_content.lower().replace("\n", ", ").replace("-", "").strip()
	scenario_content = " ".join(scenario_content.split()).strip()
	if not scenario_content:
		raise Exception("No scenario content found")
	return scenario_content

# %%
short_summary_template = PromptTemplate(
    template="""
You are a summarization assistant for a medical retrieval (RAG) system. Your job is to write a **concise, keyword-style paragraph** summarizing a single medical chapter.

## Your Inputs:
- `document`: The full text of one medical chapter's criteria.
- `chapter_list`: A list of **other chapters** that may contain overlapping or similar symptoms.
---

## chapter_list (STRICTLY EXCLUDE anything overlapping with these):
{chapter_list}
---

## Current chapter (for context):
{chapter}
---

## document (your ONLY source of truth):
{document}

## TASK INSTRUCTIONS:

1. Extract only symptoms, conditions, causes, or observable signs that are **distinctively associated with the current chapter**.
2. **Omit any information** (symptoms, words, phrases) that may also apply to chapters listed in `chapter_list`.
3. Ignore treatments, tests, procedures, advice, or questions. Include only observable, clinical features.
4. Write a **single flowing paragraph** using **keywords or short phrases** only — no complete sentences, no bullet points, no lists.
5. Do **not** paraphrase, infer, or invent. Use terms exactly as found in the document.
6. The summary must contain **exactly between 20 and 30 words**. Count and verify this before returning your output.

---

## FORMAT:
Return only the summary paragraph (no title, no formatting, no quotation marks). It must be between 20-30 words.
""",
    input_variables=["chapter_list", "document", "chapter"]
)

# %%
with open("Data/Chapter_Short_Summaries2.jsonl", "w", encoding="utf-8") as f_out:
	for i, (chapter, document) in enumerate(Content.items()):
		section_list = extract_sections_list(document)
		relevant_list = []
		for index, (header, body) in enumerate(section_list):
			header = header.strip().lower()
			body = body.strip()

			if header == "criteria":
				criteria = get_criteria(body)
				relevant_list.extend(criteria)
			elif header == "emergency response":
				scenario = get_scenario(body)
				relevant_list.append(scenario)

		relevant_text = f"Chapter: {chapter}\n\n" + format_text(list(set(relevant_list)))
		print(f"\nProcessing {i+1}/{len(Content)}: {chapter}")
		chapter_list = [cur_chapter for cur_chapter in Chapters if cur_chapter != chapter]
		chapter_str = "\n- " + "\n- ".join(chapter_list)

		while True:
			response = call_llm_template(short_summary_template, {"document": relevant_text, "chapter_list": chapter_str, "chapter": chapter})
			if not response:
				print("Error: None response from the model")
				break

			response = response.strip().replace("\n\n", "\n")
			words = len(response.split(" "))
			print(f"Response length: {words} words")
			if words < 20 or words > 30:
				print(f"Warning: Response length {words} is outside the expected range (15-20). Retrying...")
				continue
			break

		if not response:
			response = ""


		entry = {
			"chapter": chapter,
			"summary": response
		}

		print("relevant_text:\n",relevant_text)
		print("-" * 50)
		print("chapter:", chapter)
		print("summary:", response)
		print("=" * 50)

		f_out.write(
			json.dumps(entry, ensure_ascii=False) + "\n"
		)
# Out:
# Processing 1/36: 03 Unconscious / decreased level of consciousness, breathing normally
# Response length: 25 words
# relevant_text:
#  Chapter: 03 Unconscious / decreased level of consciousness, breathing normally
#
# Criteria:
#
# Temporary loss of consciousness (fainting, passing out)
# - after taking GTN
#
# free airway child, is the
# - infant (under 1 year) breathing normally?
# - child breathing normally?
# - Drowsy (decreased level of consciousness), breathing normally
# - Loss of consciousness (fainting) more than once, alert now
# - Has had a seizure (convulsions, fit), drowsy (decreased level of consciousness) and/or confused after 20 minutes
# - Unconscious adult, breathing normally
# - Has epilepsy. Gradually waking up after a seizure (convulsion, fit)
# - free airway adult, is the adult breathing normally?
# - Unconscious child, breathing normally
# --------------------------------------------------
# chapter: 03 Unconscious / decreased level of consciousness, breathing normally
# summary: Temporary loss of consciousness, fainting, drowsy, decreased level of consciousness, seizure, confused, unconscious adult, unconscious child, breathing normally, gradually waking up after seizure, alert now.
# ==================================================
#
# Processing 2/36: 04 Choking / foreign object
# Response length: 27 words
# relevant_text:
#  Chapter: 04 Choking / foreign object
#
# Criteria:
#
# - Alert, symptoms showing possible blockage in airway or throat
# - Suspect a button battery in the ear or nose
# - Suspect an object in one of the body's orifices
# - May have a battery in the airway or throat
# - Suspect a possible object in airway or throat, after a few days
# - Coughed up the object, no symptoms now
#
# still choking / blocked airway,
# - babies and infants (instruction in coughing not relevant), have you cleared the airway of baby/infant?
# - children and adults (unable to cough), have you cleared the airway of children/adult?
#
# May have an airway blockage,
# - unconscious or losing consciousness
# - difficulty breathing
# --------------------------------------------------
# chapter: 04 Choking / foreign object
# summary: Alert, possible airway blockage, symptoms of choking, button battery in ear/nose, object in orifices, coughing up object, unconsciousness, difficulty breathing, infants unable to cough, airway clearance needed.
# ==================================================
#
# Processing 3/36: 05 Mental health issue
# Response length: 25 words
# relevant_text:
#  Chapter: 05 Mental health issue
#
# Criteria:
#
# Change in state of mind and/or deterioration in already known mental health issue with:
# - Caller needs assistance
# - Known mental health issue, several calls, probably needs medical assistance
# - Frequent caller without any new problems, known mental health issue
# - Indifferent (disinterested) or major mood swings
# - Feeling low and inert (listless)
# - Change in behaviour or mood, does not have a known mental health problem
# - Report of concern. Behaving strangely, but is quiet and under control
# - Verbal threats
# - Threat of violence
# - Visual and/or auditory (hearing) hallucinations
# - Wants to talk to a doctor or others who can help
#
# Sudden change in state of mind,
# - aggressive, threatening behaviour. In immediate or imminent danger to self or others
# - very restless (troubled, agitated). In immediate or imminent danger to self or others
#
# Change in state of mind and/or deterioration in already known mental health issue with: Increasing
# - anxiety
# - restlessness and/or confusion
# --------------------------------------------------
# chapter: 05 Mental health issue
# summary: Change in state of mind, deterioration in mental health, mood swings, feeling low, strange behavior, verbal threats, hallucinations, aggressive behavior, restlessness, anxiety, confusion, immediate danger.
# ==================================================
#
# Processing 4/36: 06 Mental health crisis - suicide risk
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt4o-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with o1_mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41_nano...
# Response length: 25 words
# relevant_text:
#  Chapter: 06 Mental health crisis - suicide risk
#
# Criteria:
#
# Risk of suicide:
# - Feeling low and inert (listless)
# - Report of concern, assessed to be less serious
# - Self-harm, minor injury or poisoning. Alert and breathing normally
# - Injury, not in immediate need of an ambulance
# - May have taken toxic substances, not in immediate need of an ambulance
# - Has a self-harm problem, minor injuries due to self-harm and/or feels the need to self-harm
#
# Serious suicide attempt:
# - drowning
# - Immediate risk of suicide after assessment
# - Report of concern, acute risk of suicide If risk factors are present - assess suicide risk
# - jumping from a heigh
# - Serious risk of suicide and immediately available method. Has concrete plans and is well prepared
# - Deep cuts and major blood loss
# - Hanging
#
# Risk of suicide: Report of
# - concern related to a patient with suicidal thoughts
# - has anything particular happened to you in terms (suicide assessment)?
# - suicidal thoughts or suicidal plans (suicide assessment)?
# - immediate risk of suicide (on a rail track, ready to jump, has a weapon; gun, knife, rope around the neck, in the midst of traffic)?
# - is the person in immediate risk of suicide?
# - Unconscious (unresponsive)
#
# Serious suicide attempt: Involving
# - other method of injury or other damaging situation
# - gases or carbon monoxide
#
# Serious suicide attempt: Involving a
# - dangerous amount of medication or other toxic substance
# - weapon
#
# Risk of suicide: Wants to talk to a doctor or others who can
# - help. Feels depressed or has suicidal thoughts
# - help
# --------------------------------------------------
# chapter: 06 Mental health crisis - suicide risk
# summary: Feeling low, listless, self-harm, minor injuries, suicidal thoughts, acute risk, concrete plans, deep cuts, major blood loss, immediate risk, weapon involvement, toxic substances, wants help.
# ==================================================
#
# Processing 5/36: 07 Burns
# Response length: 28 words
# relevant_text:
#  Chapter: 07 Burns
#
# Criteria:
#
# Partial thickness or superficial
# - burns on the face, hands, genitals or close to joints
#
# Partial thickness or superficial burns:
# - Adult (less than 15 % of the skin)
# - Involved in an accident, no symptoms
# - Low voltage current (230V) passing through the body, still unwell
# - Over 65 years (less than 10 % of the skin)
# - Exposed to smoke, no symptoms at the moment
# - Minor burns (less than 1 % of the skin)
# - Child (less than 10 % of the skin)
#
# Serious burns injury or full thickness burns:
# - Over 65 years
# - Child
# - Adult
#
# Exposed to smoke or toxic gases from a fire:
# - Difficulty talking, swallowing, coughing or is hoarse
# - Soot particles in the nose, mouth or spit
# - Drowsy (decreased level of consciousness), confused and/or irritable
# - Other serious or extensive injury in addition to burns
# - May have a serious injury due to fire, smoke, scalding or electricity
# - Shortness of breath or difficulty breathing
# - Missing persons in connection with a fire
# - Injury due to high voltage electric current or lightning
# - Fall from a height and electricity passing through the body at the same time
# - Unconscious (unresponsive)
# - injury or full thickness burns in the face, hands or genitals
# - Low voltage current (230V) and has been stuck to the source
#
# Serious burns injury or full thickness
# - burns after exposure to chemicals
# --------------------------------------------------
# chapter: 07 Burns
# summary: Partial thickness burns on face, hands, genitals, or joints; serious burns in children or elderly; smoke exposure; difficulty talking, swallowing, or breathing; soot in mouth; unresponsive; chemical burns.
# ==================================================
#
# Processing 6/36: 08 Drowning
# Response length: 26 words
# relevant_text:
#  Chapter: 08 Drowning
#
# Criteria:
#
# - Has been under water for a short time, now alert and breathing normally
# - Coughing, breathing normally
# - Could have inhaled water, no other symptoms
# - Seems cold, unable to find shelter and warmth
# - Is extremely cold, drowsy (decreased level of consciousness)
# - Seems cold after being in the water, no other symptoms
# - Shortness of breath or difficulty breathing Cold (hypothermic) patients may have a very weak pulse and shallow breathing
# - Danger of (or suspected) moderate, severe or profound hypothermia
# - Disorientated, but breathing normally
# - Unconscious (unresponsive)
# - Person in danger in the water
# - Exhausted (worn-out, fatigued), but alert and breathing normally
# - Diving accident, possible neck injury
# - Fallen into water from a height (bridge, scaffolding etc.)
# - Major external injury
# - Missing persons in or by water
# --------------------------------------------------
# chapter: 08 Drowning
# summary: Under water for a short time, alert and breathing normally, coughing, cold, drowsy, shortness of breath, disorientated, unconscious, exhausted, diving accident, major external injury, missing persons.
# ==================================================
#
# Processing 7/36: 09 Scuba diving accident
# Response length: 25 words
# relevant_text:
#  Chapter: 09 Scuba diving accident
#
# Criteria:
#
# - Headache within 24 hours of a scuba dive
# - Pale, clammy skin (cold sweating) immediately after a scuba dive
# - Shortness of breath or difficulty breathing, chest pain or severe, persistent cough immediately after a scuba dive
# - Anxious about a scuba diving injury, no symptoms or problems now
# - Scuba diver in the water with possible injury (bystanders may have started search and rescue)
# - Scuba diver missing (bystanders may have started search and rescue)
# - Numbness or tingling in the skin within 24 hours of a scuba dive
# - Skin or joint pain within 24 hours of a scuba dive
# - Rash or itching within 24 hours of a scuba dive
# - Unconscious (unresponsive) immediately after a scuba dive
# - Major external injury
#
# Exhausted (worn-out, fatigued)
# - and drowsy (decreased level of consciousness) immediately after a scuba dive
# - or drowsy (decreased level of consciousness) within 24 hours of a scuba dive
#
# Paralysis or numbness in parts of the body
# - immediately after a scuba dive
# - within 24 hours of a scuba dive
#
# Danger of (or suspected)
# - moderate, severe or profound hypothermia
# - mild hypothermia related to scuba diving
# --------------------------------------------------
# chapter: 09 Scuba diving accident
# summary: Headache, pale clammy skin, shortness of breath, chest pain, numbness, tingling, skin or joint pain, rash, itching, unconsciousness, major external injury, fatigue, drowsiness, paralysis, hypothermia.
# ==================================================
#
# Processing 8/36: 10 Chemicals / gasses / CBRN
# Response length: 27 words
# relevant_text:
#  Chapter: 10 Chemicals / gasses / CBRN
#
# Criteria:
#
# - Ingested corrosive liquid, Patient must go to A&E if s/he has swallowed liquid corrosives
# - Possible serious injury involving hazardous materials
# - Leakage of toxic or explosive gases
# - Unconscious (unrepsonsive) following an incident involving hazardous materials
# - Minor superficial corrosive injury (less than 1 % of the skin)
# - Has ingested a small amount of corrosive liquid, no symptoms
# - Inhaled damaging chemical material or gas, no symptoms
# - Severe shortness of breath
# - Drowsy (decreased level of consciousness) or restless
# - Pale, clammy skin (cold sweating)
# - Minor poisoning, uncertain information
# - Incident with hazardous materials
# - Exposed to small amounts of toxic material eller gas, no other symptoms
# - Corrosive injury in the face or eye
#
# Superficial corrosive injury -
# - Child - less than 10 % of the skin
# - Over 65 years - less than 10 % of the skin
# - Adult - less than 15 % of the skin
# - In the eye
#
# Corrosive injury on the skin -
# - Adult - deep burns and/or more than 10 - 15 % of the skin
# - Child - deep burns and/or more than 5 - 10 % of the skin
# - Over 65 years - deep burns and/or more than 10 % of the skin
#
# Ingested an oil-based or petroleum product,
# - no cough - e.g. lighter fluid, white spirit, lamp oil, paraffin, petrol or diesel
# - bad cough e.g. lighter fluid, white spirit, lamp oil, paraffin, petrol or diesel
# --------------------------------------------------
# chapter: 10 Chemicals / gasses / CBRN
# summary: Ingested corrosive liquid, leakage of toxic gases, unconscious after hazardous materials incident, severe shortness of breath, pale clammy skin, corrosive injury to face or eye, minor poisoning.
# ==================================================
#
# Processing 9/36: 11 Accident / injury
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt4o-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with o1_mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41_nano...
# Response length: 27 words
# relevant_text:
#  Chapter: 11 Accident / injury
#
# Criteria:
#
# - Severe pain or deformity in the face, shoulder, ribs, arm, hand, neck of femur, knee, ankle, foot (possible fracture or joint injury), look out for reduced sensation in the extremities
# - Injury from a high pressure jet water cleaner or air compressor
# - Danger og hypothermia / low body temperature
# - Suspect serious injury
# - Severe pain in the head, neck, chest, pelvis or thigh
# - Head injury, remembers little about what happened. Is nauseous, dizzy, intoxicated or drunk
# - Suspect a deep cut, stab wound or gunshot wound
# - Possible broken ribs
# - Injury to the face or throat, possible threat to airway
# - Major open wound, broken bone ends protruding from the wound
# - Pain in the neck or back, no loss of sensation in the arms and legs
# - Pale, clammy skin (cold sweating)
# - Has an injury, high risk patient
# - Severed limb
# - Wound, badly contaminated (soil, dirty water etc.)
# - Weakness or loss of sensation in the legs. newly observed neurological symptoms (suspect neck or back injury)
# - Gaping wound, may need stitches
# - Deep wound or cut in the arm or leg (suspect possible tendon or nerve injury)
# - Injured or dislodged tooth
# - Head injury with newly observed neurological symptoms
# - Shortness of breath or difficulty breathing
# - Major blood loss
# - Dark circles (bruising) around both eyes after a head injury
# - Wound infection, abscess or puncture wound from a dirty or infected needle
# - Bleeding that has stopped or can be stopped
# - Trapped casualty
# - Burns injury
# - Unconscious (unresponsive)
#
# Fall from a
# - significant height
# - moderate height, seems unaffected at the moment
#
# Has been unconscious,
# - alert now
# - more alert now
# --------------------------------------------------
# chapter: 11 Accident / injury
# summary: Severe pain or deformity, possible fracture, head injury, major open wound, gaping wound, weakness or loss of sensation, shortness of breath, major blood loss, trapped casualty, unconscious.
# ==================================================
#
# Processing 10/36: 12 Major incident
# Response length: 27 words
# relevant_text:
#  Chapter: 12 Major incident
#
# Criteria:
#
# - Immediate assistance required by other emergency services
# - Imminent mass-casualty incident
# - Avalanche, landslip (landslide)
# - Gas leak, major incident
# - Accident on offshore installation
# - Act of terror / act of war
# - Possible mass-casualty incident
# - Ongoing shooter incident / intentional mass-casualty incident
# - Major incident with dangerous goods or radiation hazard (CBRN and explosives)
# - Shipping accident
# - Fire or explosion on land
# - Other natural disaster
# - Road traffic accident
# - Railway, tram or trolleybus accident
# - Other major accident / mass-casualty incident
# - Plane crash
# --------------------------------------------------
# chapter: 12 Major incident
# summary: Immediate assistance required, mass-casualty incident, avalanche, landslip, gas leak, offshore accident, act of terror, ongoing shooter incident, dangerous goods, shipping accident, fire, explosion, natural disaster, plane crash.
# ==================================================
#
# Processing 11/36: 13 Road traffic accident - RTA
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt4o-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with o1_mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41_nano...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# '- Warning: FAILED to generate criteria for empty categories.'
# Error: None response from the model
# relevant_text:
#  Chapter: 13 Road traffic accident - RTA
#
# Criteria:
#
# - Severe pain in the head, neck, chest, pelvis or thigh
# - Suspect a serious injury
# - Involved in a traffic accident, no symptoms at this time
# - Weakness or loss of sensation in the legs (suspect neck or back injury) Look out for numbness or loss of sensation.
# - Injury to the face or throat, possible threat to airway
# - Slight pain or discomfort in the neck, no additional symptoms
# - Pain in the neck or back, no loss of sensation in the arms and legs
# - Head injury - remembers little about what happened. May also be nauseous or dizzy
# - Danger og hypothermia / low body temperature Se 31 Hypotermi
# - Pale, clammy skin (cold sweating)
# - Has an injury, high risk patient
# - Gaping wound, may need stitches
# - Shortness of breath or difficulty breathing
# - Major blood loss
# - Severe pain or deformity in the face, shoulder, ribs, arm, hand, neck of femur, knee, ankle, foot (possible fracture or joint injury)
# - Major open wound and/or broken bone ends protruding from the wound
# - Bleeding that has stopped or can be stopped
# - Trapped casualty
# - Unconscious (unresponsive)
#
# Has been unconscious,
# - alert now
# - more alert now
# --------------------------------------------------
# chapter: 13 Road traffic accident - RTA
# summary:
# ==================================================
#
# Processing 12/36: 14 Violence / abuse
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt4o-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with o1_mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41_nano...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# '- Warning: FAILED to generate criteria for empty categories.'
# Error: None response from the model
# relevant_text:
#  Chapter: 14 Violence / abuse
#
# Criteria:
#
# - Sexual violence
# - Danger of serious violence
# - Possible abuse
# - Shortness of breath or difficulty breathing
# - Severe pain or deformity in the face, shoulder, ribs, arm, hand, neck of femur, knee, ankle, foot (possible fracture or joint injury)
# - Severe pain
# - Has been unconscious, alert now
# - Aggressive person threatening violence
# - Minor injuries (cuts and bruises) Se 11 Skade
# - Blunt force to the throat
# - Bleeding that has stopped or can be stopped
# - Unconscious (unresponsive)
#
# Violence, has been or is being abused -
# - Pale, clammy skin (cold sweating)
# - Weakness or loss of sensation in the legs, newly observed neurological symptoms (suspect neck or back injury)
# - Major blood loss, still bleeding
# - Alert but decreasing consciousness (fainting)
# - Injury due to knifing, shooting or blunt weapon
#
# Victim of violence
# - without injury
# - with acute psychological reaction
# --------------------------------------------------
# chapter: 14 Violence / abuse
# summary:
# ==================================================
#
# Processing 13/36: 15 Allergic reaction
# Response length: 24 words
# relevant_text:
#  Chapter: 15 Allergic reaction
#
# Criteria:
#
# - Mild allergic reaction, getting worse
# - Allergic reaction more than 30 mins after exposure
# - Anaphylactic reaction earlier, same trigger now
# - Has used an epinephrine autoinjector (EpiPen®), possibly not getting better
# - Blocked or runny nose, sudden onset
# - Still unwell following an allergic reaction more than 30 mins. ago
# - Itching and rash, no other symptoms
# - Unconscious (unresponsive)
# - Drowsy (decreased level of consciousness), restless and/oranxious
# - Difficulty swallowing
# - Difficulty talking coherently
# - Pale, clammy skin (cold sweating)
# - Anaphylactic reaction, rapidly getting worse
# - Difficulty speaking, may have a swollen tongue
# - Anxious about a possible allergic reaction, due to an earlier reaction to the same trigger
# - Anxious about an allergic reaction, no symptoms
# - Shortness of breath or difficulty breathing
# --------------------------------------------------
# chapter: 15 Allergic reaction
# summary: Mild allergic reaction worsening, more than 30 mins post-exposure, previous anaphylaxis, EpiPen® used, unresponsive, drowsy, difficulty swallowing/talking, pale clammy skin, shortness of breath, anxious.
# ==================================================
#
# Processing 14/36: 16 Child / infant - illness
# Response length: 27 words
# relevant_text:
#  Chapter: 16 Child / infant - illness
#
# Criteria:
#
# Has a fever
# - (temperature), a cold, a sore throat, an earache or is coughing
#
# Has a fever (high temperature) and a rash -
# - Generally unwell
# - Coughing non-stop, generally unwell
# - Seems very irritable
# - Diabetes or is immunocompromised
# - Persistent abdominal pain, generally unwell
# - Seems cold, weak and tired
# - Generally unwell (infant or child), repeated calls
# - Has a rash, otherwise fine
# - Parents assess child as ill
# - Diarrhoea or vomiting, generally unwell
# - Stinging when peeing
# - Infant or child over 3 months with fever, does not seem weak and tired
# - Shortness of breath or difficulty breathing
# - Pain in waves and/or bloody and slimy poo
# - Breathing problems, seems fine otherwise
# - Infant under 3 months with fever
# - Possible child abuse
# - Difficulty making contact with the child, deteriorating rapidly
# - Unconscious (unresponsive)
# - Drowsy (decreased level of consciousness). Pale, clammy skin (coldsweating)
# - Has had a seizure (convulsions, fitting), has never had febrile seizures (febrile convulsions)
# - Tummy ache (abdominal pain), otherwise fine
# - Pain over the cheeks, forehead or eyes
#
# May have a fever (high tempersture) and seems weak - Has
# - an intense headache, neck pain or neck stiffness
# - breathing problems and barely able to swallow
# - a spotty rash that doesn't fade when a glass is rolled over it
#
# May have a fever (high tempersture) and seems weak -
# - Deteriorating by the hour
# --------------------------------------------------
# chapter: 16 Child / infant - illness
# summary: Fever, cold, sore throat, earache, cough, rash, irritability, abdominal pain, diarrhea, vomiting, stinging when peeing, shortness of breath, unconscious, drowsy, seizure, pale clammy skin, headache, neck pain.
# ==================================================
#
# Processing 15/36: 17 Bite / insect sting
# Response length: 27 words
# relevant_text:
#  Chapter: 17 Bite / insect sting
#
# Criteria:
#
# - Previous anaphylactic reaction to the same trigger
# - Sting in the throat, difficulty talking or swallowing
# - Adder / viper bite, light symptoms
# - Mild allergic reaction, getting worse
# - Deep bite wound, anywhere on the body
# - Tick bite
# - Pale, clammy skin (cold sweating)
# - Anaphylactic reaction, rapidly getting worse
# - Shortness of breath or difficulty breathing
# - Major blood loss
# - Bite that barely punctures the skin
# - Insect sting in the throat, no other symptoms
# - Alert, but decreasing consciousness
# - Allergic reaction more than 30 mins after exposure
# - Reaction only in the affected area
# - Animal bite in an area with rabies
# - Unconscious (unresponsive)
#
# Adder (viper) bite,
# - feels unwell
# - high risk patient
#
# Bitten more than 12 hours ago.
# - Fever, generally unwell, significant deterioration
# - Fever and/or painful swelling in the
# --------------------------------------------------
# chapter: 17 Bite / insect sting
# summary: Previous anaphylactic reaction, sting in throat, difficulty talking or swallowing, deep bite wound, tick bite, pale clammy skin, shortness of breath, animal bite in rabies area, unconscious.
# ==================================================
#
# Processing 16/36: 18 Bleeding - non-traumatic
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt4o-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41-mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with o1_mini...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# - Warning: Retrying with gpt41_nano...
# Error calling LLM: Azure has not provided the response due to a content filter being triggered
# '- Warning: FAILED to generate criteria for empty categories.'
# Error: None response from the model
# relevant_text:
#  Chapter: 18 Bleeding - non-traumatic
#
# Criteria:
#
# - Vomiting small amounts of fresh blood
# - Post-operative bleeding in the throat
# - Pale, clammy skin (cold sweating), still bleeding
# - Major rectal bleed
# - Bleeding after an operation or an endoscopy
# - Coughing up large amounts of fresh blood
# - Vomiting dark blood, fine otherwise
# - Moderate rectal bleed without other symptoms
# - Shortness of breath or difficulty breathing
# - Vomiting dark blood similar to coffee grounds, seems weak and tired
# - Alert, but decreasing consciousness
# - Major nosebleed lasting more than 20 mins.
# - Skin sores bleeding a little all the time
# - Coughing up small smounts of blood mixed with phlegm
# - Small amounts of blood on stools or on toilet paper
# - Vomiting large amounts of fresh blood
# - Unconscious (unresponsive)
# - Black, tarry stools without other symptoms
#
# Large amount of black, tarry
# - stools
# - stools, feels unwell, sudden onset
# --------------------------------------------------
# chapter: 18 Bleeding - non-traumatic
# summary:
# ==================================================
#
# Processing 17/36: 19 Chest pain / cardiac disease
# Response length: 28 words
# relevant_text:
#  Chapter: 19 Chest pain / cardiac disease
#
# Criteria:
#
# Chest pain or discomfort in the chest -
# - Alert, but decreasing consciousness
# - Unwell, nauseous
# - Two or more shocks from an ICD (implantable cardioverter defibrillator), no other symptoms
# - Pain radiating to the jaw, shoulder, arm or back
# - Pale, clammy skin (cold sweating)
# - Possible serious heart disease with unclear symptoms
# - Irregular or slow pulse, feels unwell
# - Sudden weakness in the arms
# - Brief effect from angina medication (GTN)
# - Feeling of irregular heartbeat
# - One shock from an ICD (implantable cardioverter defibrillator), no other symptoms
# - Sudden palpitations, no other symptoms
# - Short, sharp pains in the chest
# - Lasting effect from 1-4 doses of angina medication (GTN spray or tablets)
# - Pain or discomfort at the side of the chest
# - Shortness of breath or difficulty breathing
# - Irregular or slow pulse, no other symptoms
# - Chest pain when breathing in deeply or with movement
# - Anxious about heart disease
# - Unconscious (unresponsive)
# - Severe central chest pain lasting more than 5 minutes
# - Moderate chest pain, no other symptoms
# --------------------------------------------------
# chapter: 19 Chest pain / cardiac disease
# summary: Chest pain or discomfort, pain radiating to jaw/shoulder/arm/back, pale clammy skin, irregular/slow pulse, sudden weakness in arms, shortness of breath, severe central chest pain lasting over 5 minutes.
# ==================================================
#
# Processing 18/36: 20 Diabetes
# Response length: 27 words
# relevant_text:
#  Chapter: 20 Diabetes
#
# Criteria:
#
# - Aggressive but able to drink or eat
# - Restless and/or aggresssive, unable to drink
# - Restless, able to eat and/or drink
# - Has had a hypo, no other symptoms after taking sugary food / drink
# - Unwell and pain or discomfort in the chest, shoulder, arm or jaw
# - Is having a seizure (convulsion, fit)
# - Pale, clammy skin (cold sweating), unable to drink
# - Has a high blood sugar
# - Shortness of breath or difficulty breathing
# - Needs advice on regulating insulin, no other symptoms
# - Pale, cold and clammy skin, able to eat and/or drink
# - Fever, no other symptoms
# - Unconscious (unresponsive)
# - Infection, no other symptoms
#
# Generally unwell -
# - Pregnant with symptoms related to diabetes
# - Abdominal pain
# - Producing a lot of urine recently
#
# Generally unwell - May have a
# - high blood sugar
# - low blood sugar (hypo)
#
# Generally unwell - Has
# - a fever
# - taken too much insulin, no other symptoms
#
# Drowsy (decreased level of consciousness) - May have a
# - high blood sugar
# - low blood sugar (hypo)
# --------------------------------------------------
# chapter: 20 Diabetes
# summary: Aggressive, restless, pale, clammy skin, high blood sugar, low blood sugar (hypo), drowsy, fever, abdominal pain, producing a lot of urine, unwell, infection, symptoms related to diabetes.
# ==================================================
#
# Processing 19/36: 22 Fever / infection / sepsis
# Response length: 27 words
# relevant_text:
#  Chapter: 22 Fever / infection / sepsis
#
# Criteria:
#
# May have a fever (high temperature), generally very unwell:
# - Signs of infection within 48 hours of invasive medical treatment or examination
# - In a confused state, sudden onset
# - Seems cold, very weak and tired
# - Difficulty swallowing
# - Drowsy (decreased level of consciousness)
# - Getting worse by the hour
# - Hyperventilating
# - Light sensitivity
# - Excessive pain under the skin
# - Painful swelling, spreading rapidly
#
# May have an infection and/or seems weak and tired:
# - Very sore throat
# - Baby under 3 months with a fever
# - Confused and irritable
# - Has or has had chills and shivering
# - Intense earache or frontal headache
# - Weakened immune system (immunocompromised), has a fever
# - Rash
# - Has a rash, seems fine
# - Shortness of breath or difficulty breathing
# - Has a fever, seems fine
# - Unconscious (unresponsive)
# - Hayfever, sore throat or cough, seems fine
# - Stinging when peeing
#
# May have a fever (high temperature), generally very unwell: Has
# - an intense headache, neck pain or neck stiffness
# - a rash that doesn't fade when a glass is rolled over it
#
# Child, generally unwell:
# - Persistent cough
# - Diarrhoea and / or vomiting
# --------------------------------------------------
# chapter: 22 Fever / infection / sepsis
# summary: Fever, high temperature, very unwell, signs of infection, confused state, cold, weak, difficulty swallowing, hyperventilating, light sensitivity, excessive pain, painful swelling, sore throat, chills, rash, neck pain.
# ==================================================
#
# Processing 20/36: 23 Poisoning - not related to alcohol or drugs
# Response length: 25 words
# relevant_text:
#  Chapter: 23 Poisoning - not related to alcohol or drugs
#
# Criteria:
#
# May have ingested a
# - corrosive substance, no airway symptoms, no hoarseness or difficulty swallowing E.g. drain unblocker/cleaner, lye, caustic soda, strong acids
# - small amount of a toxic substance, no symptoms
#
# May have ingested a potentially dangerous amount of a toxic substance
# - Assess the amount taken. In certain cases this could be a RED response (emergency)
#
# May have ingested a potentiallly dangerous amount of a toxic substance - Has
# - ingested a corrosive substance causing swallowing difficulties E.g. drain unblocker/cleaner, lye, caustic soda, strong acids
# - swallowed a battery, eg. a button battery, has symptoms
#
# May have ingested a potentially dangerous amount of a toxic substance -
# - The situation requires immediate treatment to avoid serious symptoms or injury. Assess the amount taken. In certain cases this could be a YELLOW response (urgent)
# - Pale, clammy skin (cold sweating)
# - Serious or continuing (persistent, lasting) airway symptoms
# - Difficulty swallowing
# - Is having a seizure (convulsion, fit)
# - Suspect self inflicted injury or neglect
# - Unconscious (unresponsive)
# - Ingested an oil-based or petroleum product, no cough E.g. lighter fluid, white spirit, lamp oil, paraffin, petrol or diesel
# --------------------------------------------------
# chapter: 23 Poisoning - not related to alcohol or drugs
# summary: Corrosive substance ingestion, no airway symptoms, swallowing difficulties, toxic substance exposure, pale clammy skin, serious airway symptoms, difficulty swallowing, seizure, self-inflicted injury, oil-based product ingestion.
# ==================================================
#
# Processing 21/36: 24 Functional decline
# Response length: 27 words
# relevant_text:
#  Chapter: 24 Functional decline
#
# Criteria:
#
# - Feels generally very unwell, onset within the last 24 hours
# - Unable to do everyday chores, gradual onset 48 hours or longer
# - Has fallen, may have a serious injury
# - Feels generally unwell, onset over the last 24 - 48 hours
# - Found on the floor or on the ground. Lacking further information, may have been lying there for a while
# - Pale, clammy skin (cold sweating)
# - Psychosocial problem - carers unavailable, Sudden functional decline must be kept separate from situations where the patient’s network fails, whilst s/he remains unchanged.
# - Fall or found on the floor, now feeling better. May have an injury and/or can't explain what has happened
# - Shortness of breath or difficulty breathing
# - Feels ill and has no energy, sudden onset
# - Fall / found on the floor and can´t get up, no symptoms
# - Unconscious (unresponsive)
#
# Altered level of consciousness and lack of
# - awareness, gradual onset 48 hours or longer
# - awareness (suspect delirium), developing over the last 24-48 hours
#
# Malnutrition or not eating enough, feels
# - fine otherwise
# - gernerally unwell
#
# Dehydration or not getting enough fluids, feels
# - generally unwell
# - fine otherwise
#
# Increasing tendency to fall,
# - developing over the last 24-48 hours
# - gradual onset 48 hours or longer
#
# Falling asleep during a consultation/check-up,
# - gradual onset 48 hours or longer
# - possible emergency situation (suspect delirium), developing over the last 24-48 hours
# --------------------------------------------------
# chapter: 24 Functional decline
# summary: General unwellness, onset 24-48 hours, inability to perform chores, falls, pale clammy skin, psychosocial issues, shortness of breath, altered consciousness, malnutrition, dehydration, increasing falls, sleepiness during consultation.
# ==================================================
#
# Processing 22/36: 25 Childbirth
# Response length: 24 words
# relevant_text:
#  Chapter: 25 Childbirth
#
# Criteria:
#
# The baby is coming -
# - Normal position (head first)
# - The head is not presenting first (breech)
# - Has been diagnosed with pre-eclampsia. Has a headache, disturbed vision or restlessness
# - Is having a seizure (convulsion, fitting)
# - Shortness of breath or difficulty breathing
# - Major bleeding
# - Unconscious (unresponsive)
#
# Full-term (week 37-40) -
# - The baby is born, mother and baby seem to be fine.
# - Tightening or contracions, not regular or strong
#
# Full-term (week 37-40) - Given birth previously,
# - less that 5 minutes between strong, regular contractions
# - more than 5 minutes between contractions
#
# Less than 37 weeks pregnant -
# - Some vaginal bleeding
# - Persistent or severe pain or contractions
# - Tightening or contractions, not continuous or strong
# - The baby shows ittle or no activity
#
# Less than 37 weeks pregnant - Waters have broken,
# - no contractions
# - contractions
#
# The baby is not in a normal position -
# - Waters have broken
# - Strong contractions
#
# Full-term (week 37-40) - First time mother,
# - more than 2 minutes between contractions
# - less than 2 minutes between strong, regular contractions
#
# Pain or contractions -
# - Waters have broken
# - Vaginal bleeding
# - After a blow to the abdomen (after 20th week of pregnancy)
#
# The baby is born -
# - Very premature (before week 37)
# - The mother is still bleeding profusely
# - Weak and not breathing normally
# --------------------------------------------------
# chapter: 25 Childbirth
# summary: Normal position (head first), breech presentation, pre-eclampsia (headache, disturbed vision, restlessness), seizures, shortness of breath, major bleeding, unconsciousness, vaginal bleeding, weak baby, no activity.
# ==================================================
#
# Processing 23/36: 26 Gynecology / pregnancy
# Response length: 28 words
# relevant_text:
#  Chapter: 26 Gynecology / pregnancy
#
# Criteria:
#
# Pregnant and -
# - Having a fitting / convulsion / seizure
# - Intense abdominal pain
# - Contractions between weeks 20 and 36
# - Significant vaginal bleeding
# - Vaginal bleeding or abdominal pain after a blow to the stomach
#
# Pregnant, over 20 weeks - Minor
# - vaginal bleeding
# - contractions or abdominal pain
# - Has been diagnosed with pre-eclampsia. Has a headache, disturbed vision or restlessness
# - Miscarriage before week 20
# - Vaginal bleeding, pale, clammy skin (cold sweating)
# - Fever and pain and/or discomfort in the lower abdomen
# - Shortness of breath or difficulty breathing
# - Alert, but decreasing consciousness
# - Vaginal bleeding, significantly more than normal menstruation (period)
# - Unconscious (unresponsive)
#
# Pregnant less than 20 weeks -
# - Abdominal pain
# - Anxious after a blow to the stomach
# - Not pregnant. Abnormal pain or bleeding, no other symptoms
# - Vaginal bleeding
#
# Acute abdominal pain,
# - pregnancy cannot be ruled out
# - pale, clammy skin (cold sweating)
#
# Pregnant, over 20 weeks -
# - Increasing headaches or blurring of vision
# - Anxious after a blow to the stomach
# - Unexpected intense pain, discomfort or bleeding after an induced abortion
# - Generally unwell, fever and painful swelling in one breast
# --------------------------------------------------
# chapter: 26 Gynecology / pregnancy
# summary: Pregnant, fitting/seizure, intense abdominal pain, contractions (20-36 weeks), significant vaginal bleeding, abdominal pain after blow, pre-eclampsia (headache, disturbed vision), vaginal bleeding, pale clammy skin, fever, shortness of breath.
# ==================================================
#
# Processing 24/36: 27 Stroke symptoms
# Response length: 27 words
# relevant_text:
#  Chapter: 27 Stroke symptoms
#
# Criteria:
#
# Sudden and continuing (persistent, lasting), This includes symptoms that improve and/or the patient had on waking up -
# - Loss of sensation (feeling) when touched (stroked) on an arm, leg or face and arm
# - Dizziness, unsteadiness, confusion, disorientation, difficulty controlling movement of an arm and/or leg
# - Changes in vision (blurred vision, double vision or loss of vision in one eye)
# - Dificulty lifting or holding up an arm or a leg, or weakness (paralysis) on one side
# - Atypical and intense headache
# - Has just experienced possible stroke symptoms, no symptoms now. If symptoms occur repeatedly: Check info PAY SPECIAL ATTENTION TO
# - Unconscious (unresponsive)
# - Repeated dizzy spells, stroke unlikely
# - Alert, but decreasing consciousness. Pale, clammy skin (cold sweating)
# - Shortness of breath or difficulty breathing
#
# Sudden and continuing (persistent, lasting), This includes symptoms that improve and/or the patient had on waking up - Difficulty
# - talking (slurred or garbled speech, babbling, looking for words)
# - smiling (face dropping to one side, asymmetrical face)
# --------------------------------------------------
# chapter: 27 Stroke symptoms
# summary: Sudden loss of sensation, dizziness, confusion, difficulty controlling movement, changes in vision, weakness on one side, atypical headache, slurred speech, asymmetrical face, decreased consciousness, pale clammy skin.
# ==================================================
#
# Processing 25/36: 28 Headache
# Response length: 23 words
# relevant_text:
#  Chapter: 28 Headache
#
# Criteria:
#
# Sudden atypical and intense headache -
# - Headache and in a confused state all of a sudden
# - Light sensitivity or changes in vision (blurred vision, double vision or loss of vision in one eye)
# - Altered level of consciousness
# - Pale, clammy skin (cold sweating)
# - Difficulty talking
# - Nauseous
# - Paralysis or numbness
# - Seizure (fitting / convulsions)
# - Abnormal, intense headache, no other symptoms
# - Headache, no other symptoms
# - Has had brain surgery, increasingly intense headache
# - Pregnant with atypical and increasingly intense headache
# - Shortness of breath or difficulty breathing
# - Frontal headache, fever and blocked nose
# - Has just taken angina medication (GTN)
# - Suffers from migraine, attack now
# - Unconscious (unresponsive)
#
# Blow to the head
# - within the last 24 hours, increasing headache
# - more than 24 hours ago, increasing headache
# - , is on anticoagulants
#
# Seems hot (febrile) -
# - Has a spotty rash that doesn’t fade when a glass is rolled over it
# - Feels generally unwell, has an intense headache, neck pain or neck stiffness
# --------------------------------------------------
# chapter: 28 Headache
# summary: Sudden atypical headache, light sensitivity, blurred vision, altered consciousness, nausea, paralysis, seizure, increasing headache post-head injury, febrile with neck pain, spotty rash, anticoagulants.
# ==================================================
#
# Processing 26/36: 29 Skin / rash
# Response length: 28 words
# relevant_text:
#  Chapter: 29 Skin / rash
#
# Criteria:
#
# - Pain under the skin, unclear cause
# - Seems gererally unwell, has a rash
# - Has a spotty rash that don't fade when a glass is rolled over it
# - Itchy rash
# - Rash and/or sore on or near the genitals
# - Shortness of breath or difficulty breathing
# - Rash, seems fine
# - May have lice or scabies
# - Rash over a limited area of the skin
# - Pain and swelling or tenderness in the limbs
# - Itchy rash, feels unwell
# - Fever and painful swelling in or under the skin
# - Unconscious (unresponsive)
# - Chronic skin condition or rash
# - Rash covering much of the body
#
# Has a rash and - May be febrile,
# - generally unwell
# - deteriorating by the hour
#
# Has a rash and -
# - Drowsy (decreased level of consciousness). Pale, clammy skin (cold sweating)
# - Intense headache, neck pain or neck stiffness
# - Fever and intense pain deep under the skin
# - Allergic rash, rapid deterioration (has reacted to the same trigger earlier)
# - Painful swelling that is spreading fast
# --------------------------------------------------
# chapter: 29 Skin / rash
# summary: Pain under the skin, unclear cause, spotty rash, itchy rash, rash near genitals, lice or scabies, fever, chronic skin condition, rash covering much of the body, painful swelling.
# ==================================================
#
# Processing 27/36: 30 Hyperthermia / heat stroke / heat exhaustion
# Response length: 26 words
# relevant_text:
#  Chapter: 30 Hyperthermia / heat stroke / heat exhaustion
#
# Criteria:
#
# Possible hyperthermia (heatstroke) or has been exposed to extreme heat -
# - Drowsy (decreased level of consciousness)
# - Seizure (convulsions, fit)
# - Shortness of breath or difficulty breathing
# - Weak and tired after abnormal and/or demanding physical exercise
# - Has taken drugs
# - Very rapid pulse
# - Completely passive (uninterested, complacent, detatched)
# - Unconscious (unresponsive)
#
# Exposed to extreme heat -
# - Very dizzy
# - Unwell
# - Weak and tired
# - Rapid pulse
# - Headache
# - Prolonged exertion in a hot climate and muscle cramps
# - Exposure to extreme heat, no other symptoms
# --------------------------------------------------
# chapter: 30 Hyperthermia / heat stroke / heat exhaustion
# summary: Drowsy, very dizzy, unwell, weak, tired, rapid pulse, headache, muscle cramps, shortness of breath, completely passive, unconscious, exposure to extreme heat, prolonged exertion in hot climate.
# ==================================================
#
# Processing 28/36: 31 Hypothermia / cold person
# Response length: 24 words
# relevant_text:
#  Chapter: 31 Hypothermia / cold person
#
# Criteria:
#
# Seems to have a low body temperature -
# - Is weak and/or worn out (exhausted, tired)
# - Unconscious (unresponsive)
# - Helpless and in danger of becoming even colder
# - Has additional major injury
# - Very passive (disinterested, detatched)
# - Drowsy (decreased level of consciousness)
# - Shortness of breath or difficulty breathing
# - May have deep or severe frostbite (hard, stiffened skin with loss of sensation)
# - Has been very cold, body temperature measures ca.36-35 ºC, no other symptoms
# - Has been exposed to extreme cold, no other symptoms
# - May have superficial frostbite (painful skin, but remains soft)
#
# Seems to have a low body
# - temperature, repsonsive and no other symptoms
# --------------------------------------------------
# chapter: 31 Hypothermia / cold person
# summary: Low body temperature, weak, exhausted, unconscious, helpless, passive, drowsy, shortness of breath, severe frostbite, hard skin, loss of sensation, superficial frostbite, extreme cold exposure.
# ==================================================
#
# Processing 29/36: 32 Seizures (convulsions, fits)
# Response length: 23 words
# relevant_text:
#  Chapter: 32 Seizures (convulsions, fits)
#
# Criteria:
#
# Has had a seizure (convulsions, fit) - Is
# - a diabetic
# - warm, has a spotty rash that doesn’t fade when a glass is rolled over it
# - pregnant
#
# Has had a seizure (convulsions, fit) -
# - Infant or small child, may have a fever, has never had febrile seizures (febrile convulsions)
# - Cannot be roused, the seizure ended more than 20 minutes ago
# - Spasms in one part of the body (arm or leg), drowsy (decreased level of consciousness) and/or confused
# - Still drowsy (decreased level of consciousness) and/or confused after more than 20 minutes
# - Recent injury to the head
# - Lasting more than 5 minutes
# - Several seizures one after the other without waking up
# - The seizure lasted less than 5 minutes
# - Infant or small child, has had a seizure (convulsions / fit). May have a fever, has had febrile convulsions earlier
# - Has epilepsy. Has had a seizure (convulsions, fit), gradually regaining consciousness
# - Shortness of breath or difficulty breathing
# - Spasms in one part of the body (arm eller leg). Fully alert
# - Ongoing convulsions, has epilepsy
# - Unconscious (unresponsive)
# - Ongoing seizure (convulsions, fitting), not known to have epilepsy
#
# Has had a seizure (convulsions, fit) - Has
# - epilepsy, still unconscious (unresponsive)
# - drunk a lot of alcohol recently
# --------------------------------------------------
# chapter: 32 Seizures (convulsions, fits)
# summary: Seizure (convulsions, fit), diabetic, pregnant, infant/child, fever, prolonged unconsciousness, lasting over 5 minutes, multiple seizures, recent head injury, ongoing convulsions, drowsy, confused, unresponsive.
# ==================================================
#
# Processing 30/36: 33 Breathing problems
# Response length: 29 words
# relevant_text:
#  Chapter: 33 Breathing problems
#
# Criteria:
#
# - Young person with rapid breathing, a feeling of not gettting enough air. Anxiety, tingling around the mouth, in the fingers. Non-risk patient, seems well, simple measures are not helping
# - Significant difficulty breathing, Check info SIGNIFICANT BREATHING PROBLEMS
# - Has a known lung condition (illness)
# - Has has panic attacks and/or hyperventilated earlier, the patient is easily calmed during the call and is being taken care of
# - Moderate breathing problems, Check info MODERATE BREATHING DIFFICULTIES
# - Pale, clammy skin (cold sweating)
# - Unable to swallow spit, dribbling
# - Pain or discomfort in the chest
# - Coughing non-stop, seems weak and tired
# - Gurgling in the chest, frothy spit
# - Alert, but decreasing consciousness
# - Has a lung condition (illness), is worried it might be getting worse
# - Drowsy (decreased level of consciousness), new situation with confusion and/or vagueness, Check info NEW EMERGED CONFUSION
# - Light symptoms related to breathing
# - Unconscious (unresponsive)
# - Slight difficulty breathing, Check info MILD BREATHING DIFFICULTIES
# - Injured patient with shortness of breath or difficulty breathing
#
# Health worker reporting a category
# - green respiratory rate, Check the table RESPIRATORY RATE
# - yellow respiratory rate, Check the table RESPIRATORY RATE
# --------------------------------------------------
# chapter: 33 Breathing problems
# summary: Rapid breathing, feeling of not getting enough air, anxiety, tingling around mouth, significant difficulty breathing, known lung condition, pale clammy skin, unable to swallow, cough, gurgling in chest, drowsy.
# ==================================================
#
# Processing 31/36: 34 Drug abuse / intoxication / overdose
# Response length: 27 words
# relevant_text:
#  Chapter: 34 Drug abuse / intoxication / overdose
#
# Criteria:
#
# - Agitated and out of control
# - May have taken an overdose, breathing normally. The severity depends on the amount of pills / medication / drugs, time and symptoms
# - Anxious or unwell after intoxication
# - Seems intoxicated (drunk, not sober, inebriated), difficult to rouse
# - Severely depressed, asking to talk to a doctor or to others who can help
# - Barely breathing (weak breathing, slow breathing)
# - Alcohol intoxication, no other medical problems
# - Has taken central nervous system stimulants, unwell or extremely hot e.g. cocaine, amphetamines, ecstacy
# - Agressive and threatening violence
# - Threatening to take an overdose
# - Intoxicated (drunk), unable to take care of him/herself
# - Intoxicated or drunk and may be seriously injured
# - Pale, clammy skin (cold sweating)
# - Major risk of serious violence
# - Wants to talk to a doctor
# - Can't see properly, may have ingested methanol
# - Wants help with a drug or alcohol problem
# - Has had a seizure (convulsion, fit) lasting less than 5 minutes
# - May have methanol poisoning. Vision normal.
# - Unconscious (unresponsive)
# - Is having a conviulsion / fit / seizure
#
# Has taken a large number of
# - pills or other intoxicant, difficult to rouse
# - pills, easy to rouse when stimulated. The severity depends on the amount of pills / medication / drugs, time and symptoms
# --------------------------------------------------
# chapter: 34 Drug abuse / intoxication / overdose
# summary: Agitated, out of control, anxious, unwell, intoxicated, difficult to rouse, pale, clammy skin, aggressive, threatening overdose, seizure, may have methanol poisoning, unconscious, major risk of serious violence.
# ==================================================
#
# Processing 32/36: 35 Pain in the abdomen / back / extremities
# Response length: 29 words
# relevant_text:
#  Chapter: 35 Pain in the abdomen / back / extremities
#
# Criteria:
#
# Back pain -
# - Moderate pain in the arms or legs
# - Difficulty passing urine (peeing)
# - Fever, increasing pain in the side or back
# - Numbness in the leg or foot
# - Acute abdominal pain. Alert, but decreasing consciousness
# - Acute back pain. Alert, but decreasing consciousness
# - Severe pain coming in waves, in the abdomen, lower back or side
# - Vomiting dark blood, fine otherwise
# - Slight pain in the arms or legs
# - Fever and increasingly strong abdominal pain
# - Shortness of breath or difficulty breathing
# - Back pain, no other symptoms
# - Persistent abdominal pain, feels unwell
# - Diarrhoea or vomiting, otherwise well
# - Severe abdominal pain, seems weak and tired, or is generally unwell
# - Vomiting dark blood resembling coffee grounds, seems weak and tired
# - Unable to expel gas / cannot pass stools (poo)
# - Severe pain in the lower abdomen, could be pregnant
# - Severe persistent pain in the groin
# - Vomiting or diarrhoea, is generally unwell
# - Vomiting large amounts of fresh blood
# - Unconscious (unresponsive)
# - Abdominal pain, no other symptoms
# - Acute pain occurring suddenly in the arms or legs
# - Acute pain. Pale, clammy skin (cold sweating)
# - Severe back pain
# --------------------------------------------------
# chapter: 35 Pain in the abdomen / back / extremities
# summary: Moderate to severe abdominal pain, back pain, difficulty passing urine, fever, vomiting dark blood, acute pain in arms or legs, persistent pain, weakness, clammy skin, inability to expel gas.
# ==================================================
#
# Processing 33/36: 36 Uncertain / unidentified problem
# Response length: 27 words
# relevant_text:
#  Chapter: 36 Uncertain / unidentified problem
#
# Criteria:
#
# May have an urgent problem
# - (more information not readily available)
# - (nothing applicable in NINM)
# - Pale, clammy skin (cold sweating), sudden onset
# - Loss of consciousness (fainted) more than once
# - Repeated calls, unclear problem
# - Possible critical / serious problem (more information not readily available)
# - Unclear signs of illness within 48 hours after invasive medical treament or examination
# - Psychosocial problem
# - Alert, but decreasing consciousness
# - Unconscious (unresponsive)
# - Unwell and very frail, sudden onset
# - Difficulty communicationg, may have a serious health problem
# - Significantly weak, generally unwell, sudden onset
# - Exhausted or worn out (uncertain or unclear information)
# - Shortness of breath or difficulty breathing
#
# Assume non-urgent problem
# - (more information not readily available)
# - (nothing applicable in NINM)
# --------------------------------------------------
# chapter: 36 Uncertain / unidentified problem
# summary: Pale, clammy skin, sudden onset, loss of consciousness, repeated calls, unclear problem, psychosocial issue, alert but decreasing consciousness, unwell and frail, difficulty communicating, exhausted, shortness of breath.
# ==================================================
#
# Processing 34/36: 37 Urinary tract
# Response length: 28 words
# relevant_text:
#  Chapter: 37 Urinary tract
#
# Criteria:
#
# - Generally very unwell, intense pain
# - Stinging or pain when peeing
# - Stinging when peeing, may have a fever. Change in general condition
# - Has a urinary tract infection (UTI), possible fever. Pale, clammy skin (cold sweating)
# - Difficulty peeing
# - Increasing pain in the scrotum or groin
# - Fever and severe pain in the back
# - Discharge (pus) from the penis
# - Shortness of breath or difficulty breathing
# - Blood in the urine
# - Persistent erection, severe or moderate pain
# - Swelling or lump in the groin, no pain
# - Frequent peeing
# - Severe pain in the lower abdomen and difficulty peeing
# - Kidney transplant patient with fever and pain or producing small amounts of urine
# - Sudden, severe pain on one side of the scrotum and in the lower abdomen. May have nausea and vomiting too
# - Unconscious (unresponsive)
# - Sore on or by the genitals
# - Severe pain coming in waves, in the abdomen or lower back
# --------------------------------------------------
# chapter: 37 Urinary tract
# summary: Intense pain, stinging or pain when peeing, fever, urinary tract infection (UTI), difficulty peeing, blood in urine, severe pain in lower abdomen, swelling in groin, discharge from penis.
# ==================================================
#
# Processing 35/36: 38 Ear, nose and throat
# Response length: 27 words
# relevant_text:
#  Chapter: 38 Ear, nose and throat
#
# Criteria:
#
# - Child persistently coughing, generally unwell
# - Dizzy spells
# - Earache
# - Suddenly dizzy and unwell, stroke or TIA not suspected
# - Major nosebleed, lasting more than 20 minutes
# - Major bleeding from the nose or throat. Pale, clammy skin (cold sweating)
# - Nosebleed lasting less than 20 minutes
# - Pain over the cheeks, forehead or eyes. Worsens when bending forwards
# - Toothache
# - Shortness of breath or difficulty breathing
# - Bleeding after a throat operation
# - Possible broken nose
# - Cold, sore throat or cough, seems fine otherwise
# - Discharge from the ear, has an ear infection
# - Very sore throat, generally unwell
# - Sudden reduced hearing and dizzy without any clear reason
# - Obstruction in the throat, breathing normally
# - Unconscious (unresponsive)
# - Possible fever, difficulty swallowing
# - Post-operative bleeding in the throat, bleeding has stopped
# - Swallowed a button battery
#
# Has a foreign object in the
# - nose
# - ear canal
# --------------------------------------------------
# chapter: 38 Ear, nose and throat
# summary: Child coughing, unwell, dizzy spells, earache, major nosebleed, pain over cheeks/forehead, toothache, sore throat, discharge from ear, sudden reduced hearing, obstruction in throat, foreign object in nose/ear.
# ==================================================
#
# Processing 36/36: 39 Eye
# Response length: 28 words
# relevant_text:
#  Chapter: 39 Eye
#
# Criteria:
#
# - Red and irritated eye, no pain
# - Minor corrosive injury in or close to the eye
# - Sudden blurring of vision. Alert, but decreasing consciousness
# - Stinging or painful rash round one eye
# - Red eye, no irritation or pain
# - Sudden, extreme pain and blurring of vision in one eye, nausea and retching
# - Red, painful and irritated eye
# - Can't see properly. May have drunk methanol
# - Shortness of breath or difficulty breathing
# - Deteriorating vision in one or both eyes over the last few days
# - Has been welding. Pain and cannot see properly
# - Has been exposed to strong sun. Pain and cannot see properly
# - Black eye (bruising), no other symptoms
# - Normal vision, may have drunk methanol
# - Major injury in, or close to, the eye
# - Blow to the eye. Drowsy (decreased level of consciousness)
# - Major corrosive injury in, or close to, the eye
# - Dark circles / bruising around both eyes after a head injury
# - Unconscious (unresponsive)
# - Sudden vision loss, blurred vision, double vision or loss of vision in one eye
# - Foreign object stuck in the eye
#
# Severe, persistent pain in or
# - around the eye, no other symptoms
# - close to the eye, feels unwell
# --------------------------------------------------
# chapter: 39 Eye
# summary: Red and irritated eye, no pain; sudden blurring of vision; stinging rash; major injury; foreign object; major corrosive injury; sudden vision loss; drowsy; methanol ingestion; shortness of breath.
# ==================================================

# %%
def extract_chapter_title(content):
    pattern = r"^#\s*(.+)$"
    for i, line in enumerate(content.split("\n"), start=1):
        match = re.match(pattern, line)
        if match:
            return match.group(1).strip()
    return ""

def extract_sections_list(content):
	pattern = r'(^## (?!#).*?(?=^## (?!#)|\Z))'
	sections = re.findall(pattern, content, flags=re.MULTILINE | re.DOTALL)
	section_list = []
	for sec in sections:
		sec = sec.strip()
		lines = sec.splitlines()
		if lines:
			header = lines[0][3:].strip()  # Remove "## " prefix
			body = "\n".join(lines[1:]).strip()
			section_list.append((header, body))  # Store as a tuple
	return section_list

# %%
file_paths_json = ["Data/Json/Unique_Criteria_Scenario/" + file for file in os.listdir("Data/Json/Unique_Criteria_Scenario")]
file_paths_json.sort()

# Resolve end index if negative
resolved_end = len(file_paths_json) + end_index if end_index < 0 else end_index
indices = [i for i in range(start_index, resolved_end) if i not in exclude.tolist()]
file_paths_json = [file_paths_json[i] for i in indices]


criteria_chapter_map = defaultdict(list)
for file_path in file_paths_json:
	with open(file_path, "r", encoding="utf-8") as f:
		for line in f:
			entry = json.loads(line.strip()) 
			if not entry:
				continue
			chapter = entry.get("chapter")
			criteria = entry.get("criteria")
			criteria_chapter_map[chapter].append(criteria)
		
		

print(json.dumps(criteria_chapter_map, indent=2, ensure_ascii=False))
# Out:
# {
#   "03 Unconscious / decreased level of consciousness, breathing normally": [
#     "Unconscious adult, breathing normally",
#     "Unconscious child, breathing normally",
#     "Drowsy (decreased level of consciousness), breathing normally",
#     "Has had a seizure (convulsions, fit), drowsy (decreased level of consciousness) and/or confused after 20 minutes",
#     "Loss of consciousness (fainting) more than once, alert now",
#     "Temporary loss of consciousness (fainting, passing out)",
#     "Temporary loss of consciousness (fainting, passing out) after taking GTN",
#     "Has epilepsy. Gradually waking up after a seizure (convulsion, fit)",
#     "free airway child, is the infant (under 1 year) breathing normally?",
#     "free airway child, is the child breathing normally?",
#     "free airway adult, is the adult breathing normally?"
#   ],
#   "04 Choking / foreign object": [
#     "May have an airway blockage, unconscious or losing consciousness",
#     "May have an airway blockage, difficulty breathing",
#     "May have a battery in the airway or throat",
#     "Alert, symptoms showing possible blockage in airway or throat",
#     "Suspect a button battery in the ear or nose",
#     "Coughed up the object, no symptoms now",
#     "Suspect a possible object in airway or throat, after a few days",
#     "Suspect an object in one of the body's orifices",
#     "still choking / blocked airway, babies and infants (instruction in coughing not relevant), have you cleared the airway of baby/infant?",
#     "still choking / blocked airway, children and adults (unable to cough), have you cleared the airway of children/adult?"
#   ],
#   "05 Mental health issue": [
#     "Sudden change in state of mind, very restless (troubled, agitated). In immediate or imminent danger to self or others",
#     "Sudden change in state of mind, aggressive, threatening behaviour. In immediate or imminent danger to self or others",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Increasing anxiety",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Increasing restlessness and/or confusion",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Visual and/or auditory (hearing) hallucinations",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Verbal threats",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Threat of violence",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Indifferent (disinterested) or major mood swings",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Caller needs assistance",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Change in behaviour or mood, does not have a known mental health problem",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Known mental health issue, several calls, probably needs medical assistance",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Report of concern. Behaving strangely, but is quiet and under control",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Feeling low and inert (listless)",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Wants to talk to a doctor or others who can help",
#     "Change in state of mind and/or deterioration in already known mental health issue with: Frequent caller without any new problems, known mental health issue"
#   ],
#   "06 Mental health crisis - suicide risk": [
#     "Unconscious (unresponsive)",
#     "Serious suicide attempt: Hanging",
#     "Serious suicide attempt: Involving a dangerous amount of medication or other toxic substance",
#     "Serious suicide attempt: Involving a weapon",
#     "Serious suicide attempt: jumping from a heigh",
#     "Serious suicide attempt: drowning",
#     "Serious suicide attempt: Deep cuts and major blood loss",
#     "Serious suicide attempt: Involving gases or carbon monoxide",
#     "Serious suicide attempt: Involving other method of injury or other damaging situation",
#     "Serious suicide attempt: Serious risk of suicide and immediately available method. Has concrete plans and is well prepared",
#     "Serious suicide attempt: Immediate risk of suicide after assessment",
#     "Serious suicide attempt: Report of concern, acute risk of suicide If risk factors are present - assess suicide risk",
#     "Risk of suicide: Self-harm, minor injury or poisoning. Alert and breathing normally",
#     "Risk of suicide: May have taken toxic substances, not in immediate need of an ambulance",
#     "Risk of suicide: Injury, not in immediate need of an ambulance",
#     "Risk of suicide: Has a self-harm problem, minor injuries due to self-harm and/or feels the need to self-harm",
#     "Risk of suicide: Wants to talk to a doctor or others who can help. Feels depressed or has suicidal thoughts",
#     "Risk of suicide:  Report of concern, assessed to be less serious",
#     "Risk of suicide: Report of concern related to a patient with suicidal thoughts",
#     "Risk of suicide: Feeling low and inert (listless)",
#     "Risk of suicide: Wants to talk to a doctor or others who can help",
#     "immediate risk of suicide (on a rail track, ready to jump, has a weapon; gun, knife, rope around the neck, in the midst of traffic)?",
#     "has anything particular happened to you in terms (suicide assessment)?",
#     "suicidal thoughts or suicidal plans (suicide assessment)?",
#     "is the person in immediate risk of suicide?"
#   ],
#   "07 Burns": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "May have a serious injury due to fire, smoke, scalding or electricity",
#     "Exposed to smoke or toxic gases from a fire: Drowsy (decreased level of consciousness), confused and/or irritable",
#     "Exposed to smoke or toxic gases from a fire: Difficulty talking, swallowing, coughing or is hoarse",
#     "Exposed to smoke or toxic gases from a fire: Soot particles in the nose, mouth or spit",
#     "Serious burns injury or full thickness burns: Child",
#     "Serious burns injury or full thickness burns: Adult",
#     "Serious burns injury or full thickness burns: Over 65 years",
#     "injury or full thickness burns in the face, hands or genitals",
#     "Injury due to high voltage electric current or lightning",
#     "Other serious or extensive injury in addition to burns",
#     "Serious burns injury or full thickness burns after exposure to chemicals",
#     "Missing persons in connection with a fire",
#     "Fall from a height and electricity passing through the body at the same time",
#     "Low voltage current (230V) and has been stuck to the source",
#     "Partial thickness or superficial burns: Child (less than 10 % of the skin)",
#     "Partial thickness or superficial burns: Adult (less than 15 % of the skin)",
#     "Partial thickness or superficial burns: Over 65 years (less than 10 % of the skin)",
#     "Partial thickness or superficial burns on the face, hands, genitals or close to joints",
#     "Partial thickness or superficial burns: Exposed to smoke, no symptoms at the moment",
#     "Partial thickness or superficial burns: Low voltage current (230V) passing through the body, still unwell",
#     "Partial thickness or superficial burns: Minor burns (less than 1 % of the skin)",
#     "Partial thickness or superficial burns: Involved in an accident, no symptoms"
#   ],
#   "08 Drowning": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing Cold (hypothermic) patients may have a very weak pulse and shallow breathing",
#     "Is extremely cold, drowsy (decreased level of consciousness)",
#     "Diving accident, possible neck injury",
#     "Major external injury",
#     "Danger of (or suspected) moderate, severe or profound hypothermia",
#     "Fallen into water from a height (bridge, scaffolding etc.)",
#     "Person in danger in the water",
#     "Missing persons in or by water",
#     "Disorientated, but breathing normally",
#     "Exhausted (worn-out, fatigued), but alert and breathing normally",
#     "Coughing, breathing normally",
#     "Seems cold, unable to find shelter and warmth",
#     "Could have inhaled water, no other symptoms",
#     "Has been under water for a short time, now alert and breathing normally",
#     "Seems cold after being in the water, no other symptoms"
#   ],
#   "09 Scuba diving accident": [
#     "Unconscious (unresponsive) immediately after a scuba dive",
#     "Shortness of breath or difficulty breathing, chest pain or severe, persistent cough immediately after a scuba dive",
#     "Exhausted (worn-out, fatigued) and drowsy (decreased level of consciousness) immediately after a scuba dive",
#     "Pale, clammy skin (cold sweating) immediately after a scuba dive",
#     "Paralysis or numbness in parts of the body immediately after a scuba dive",
#     "Major external injury",
#     "Danger of (or suspected) moderate, severe or profound hypothermia",
#     "Paralysis or numbness in parts of the body within 24 hours of a scuba dive",
#     "Scuba diver in the water with possible injury (bystanders may have started search and rescue)",
#     "Scuba diver missing (bystanders may have started search and rescue)",
#     "Exhausted (worn-out, fatigued) or drowsy (decreased level of consciousness) within 24 hours of a scuba dive",
#     "Headache within 24 hours of a scuba dive",
#     "Numbness or tingling in the skin within 24 hours of a scuba dive",
#     "Skin or joint pain within 24 hours of a scuba dive",
#     "Rash or itching within 24 hours of a scuba dive",
#     "Danger of (or suspected) mild hypothermia related to scuba diving",
#     "Anxious about a scuba diving injury, no symptoms or problems now"
#   ],
#   "10 Chemicals / gasses / CBRN": [
#     "Leakage of toxic or explosive gases",
#     "Incident with hazardous materials",
#     "Unconscious (unrepsonsive) following an incident involving hazardous materials",
#     "Severe shortness of breath",
#     "Drowsy (decreased level of consciousness) or restless",
#     "Pale, clammy skin (cold sweating)",
#     "Corrosive injury on the skin - Child - deep burns and/or more than 5 - 10 % of the skin",
#     "Corrosive injury on the skin - Adult - deep burns and/or more than 10 - 15 % of the skin",
#     "Corrosive injury on the skin - Over 65 years - deep burns and/or more than 10 % of the skin",
#     "Corrosive injury in the face or eye",
#     "Ingested corrosive liquid, Patient must go to A&E if s/he has swallowed liquid corrosives",
#     "Ingested an oil-based or petroleum product, bad cough e.g. lighter fluid, white spirit, lamp oil, paraffin, petrol or diesel",
#     "Possible serious injury involving hazardous materials",
#     "Superficial corrosive injury - Child - less than 10 % of the skin",
#     "Superficial corrosive injury - Adult - less than 15 % of the skin",
#     "Superficial corrosive injury - Over 65 years - less than 10 % of the skin",
#     "Superficial corrosive injury - In the eye",
#     "Has ingested a small amount of corrosive liquid, no symptoms",
#     "Ingested an oil-based or petroleum product, no cough - e.g. lighter fluid, white spirit, lamp oil, paraffin, petrol or diesel",
#     "Inhaled damaging chemical material or gas, no symptoms",
#     "Minor poisoning, uncertain information",
#     "Minor superficial corrosive injury (less than 1 % of the skin)",
#     "Exposed to small amounts of toxic material eller gas, no other symptoms"
#   ],
#   "11 Accident / injury": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Injury to the face or throat, possible threat to airway",
#     "Has been unconscious, more alert now",
#     "Head injury with newly observed neurological symptoms",
#     "Pale, clammy skin (cold sweating)",
#     "Major blood loss",
#     "Trapped casualty",
#     "Suspect a deep cut, stab wound or gunshot wound",
#     "Severed limb",
#     "Major open wound, broken bone ends protruding from the wound",
#     "Severe pain in the head, neck, chest, pelvis or thigh",
#     "Weakness or loss of sensation in the legs. newly observed neurological symptoms (suspect neck or back injury)",
#     "Fall from a significant height",
#     "Burns injury",
#     "Danger og hypothermia / low body temperature",
#     "Suspect serious injury",
#     "Has an injury, high risk patient",
#     "Has been unconscious, alert now",
#     "Head injury, remembers little about what happened. Is nauseous, dizzy, intoxicated or drunk",
#     "Bleeding that has stopped or can be stopped",
#     "Dark circles (bruising) around both eyes after a head injury",
#     "Pain in the neck or back, no loss of sensation in the arms and legs",
#     "Severe pain or deformity in the face, shoulder, ribs, arm, hand, neck of femur, knee, ankle, foot (possible fracture or joint injury), look out for reduced sensation in the extremities",
#     "Fall from a moderate height, seems unaffected at the moment",
#     "Deep wound or cut in the arm or leg (suspect possible tendon or nerve injury)",
#     "Wound, badly contaminated (soil, dirty water etc.)",
#     "Gaping wound, may need stitches",
#     "Injury from a high pressure jet water cleaner or air compressor",
#     "Wound infection, abscess or puncture wound from a dirty or infected needle",
#     "Possible broken ribs",
#     "Injured or dislodged tooth"
#   ],
#   "12 Major incident": [
#     "Fire or explosion on land",
#     "Plane crash",
#     "Railway, tram or trolleybus accident",
#     "Road traffic accident",
#     "Major incident with dangerous goods or radiation hazard (CBRN and explosives)",
#     "Avalanche, landslip (landslide)",
#     "Other natural disaster",
#     "Gas leak, major incident",
#     "Shipping accident",
#     "Accident on offshore installation",
#     "Ongoing shooter incident / intentional mass-casualty incident",
#     "Act of terror / act of war",
#     "Other major accident / mass-casualty incident",
#     "Possible mass-casualty incident",
#     "Imminent mass-casualty incident",
#     "Immediate assistance required by other emergency services"
#   ],
#   "13 Road traffic accident - RTA": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Injury to the face or throat, possible threat to airway",
#     "Has been unconscious, more alert now",
#     "Pale, clammy skin (cold sweating)",
#     "Major blood loss",
#     "Trapped casualty",
#     "Major open wound and/or broken bone ends protruding from the wound",
#     "Severe pain in the head, neck, chest, pelvis or thigh",
#     "Weakness or loss of sensation in the legs (suspect neck or back injury) Look out for numbness or loss of sensation.",
#     "Danger og hypothermia / low body temperature Se 31 Hypotermi",
#     "Has an injury, high risk patient",
#     "Suspect a serious injury",
#     "Has been unconscious, alert now",
#     "Head injury - remembers little about what happened. May also be nauseous or dizzy",
#     "Bleeding that has stopped or can be stopped",
#     "Pain in the neck or back, no loss of sensation in the arms and legs",
#     "Severe pain or deformity in the face, shoulder, ribs, arm, hand, neck of femur, knee, ankle, foot (possible fracture or joint injury)",
#     "Gaping wound, may need stitches",
#     "Slight pain or discomfort in the neck, no additional symptoms",
#     "Involved in a traffic accident, no symptoms at this time"
#   ],
#   "14 Violence / abuse": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Violence, has been or is being abused - Alert but decreasing consciousness (fainting)",
#     "Violence, has been or is being abused - Injury due to knifing, shooting or blunt weapon",
#     "Violence, has been or is being abused - Pale, clammy skin (cold sweating)",
#     "Violence, has been or is being abused - Major blood loss, still bleeding",
#     "Violence, has been or is being abused - Weakness or loss of sensation in the legs, newly observed neurological symptoms (suspect neck or back injury)",
#     "Blunt force to the throat",
#     "Danger of serious violence",
#     "Severe pain",
#     "Has been unconscious, alert now",
#     "Severe pain or deformity in the face, shoulder, ribs, arm, hand, neck of femur, knee, ankle, foot (possible fracture or joint injury)",
#     "Bleeding that has stopped or can be stopped",
#     "Aggressive person threatening violence",
#     "Sexual violence",
#     "Possible abuse",
#     "Victim of violence with acute psychological reaction",
#     "Minor injuries (cuts and bruises) Se 11 Skade",
#     "Victim of violence without injury"
#   ],
#   "15 Allergic reaction": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Difficulty talking coherently",
#     "Difficulty swallowing",
#     "Difficulty speaking, may have a swollen tongue",
#     "Drowsy (decreased level of consciousness), restless and/oranxious",
#     "Pale, clammy skin (cold sweating)",
#     "Anaphylactic reaction earlier, same trigger now",
#     "Anaphylactic reaction, rapidly getting worse",
#     "Has used an epinephrine autoinjector (EpiPen®), possibly not getting better",
#     "Mild allergic reaction, getting worse",
#     "Still unwell following an allergic reaction more than 30 mins. ago",
#     "Anxious about a possible allergic reaction, due to an earlier reaction to the same trigger",
#     "Allergic reaction more than 30 mins after exposure",
#     "Itching and rash, no other symptoms",
#     "Blocked or runny nose, sudden onset",
#     "Anxious about an allergic reaction, no symptoms"
#   ],
#   "16 Child / infant - illness": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Drowsy (decreased level of consciousness). Pale, clammy skin (coldsweating)",
#     "May have a fever (high tempersture) and seems weak - Deteriorating by the hour",
#     "May have a fever (high tempersture) and seems weak - Has a spotty rash that doesn't fade when a glass is rolled over it",
#     "May have a fever (high tempersture) and seems weak - Has an intense headache, neck pain or neck stiffness",
#     "May have a fever (high tempersture) and seems weak - Has breathing problems and barely able to swallow",
#     "Difficulty making contact with the child, deteriorating rapidly",
#     "Seems cold, weak and tired",
#     "Generally unwell (infant or child), repeated calls",
#     "Breathing problems, seems fine otherwise",
#     "Has a fever (high temperature) and a rash - Generally unwell",
#     "Has a fever (high temperature) and a rash - Seems very irritable",
#     "Has a fever (high temperature) and a rash - Coughing non-stop, generally unwell",
#     "Has a fever (high temperature) and a rash - Persistent abdominal pain, generally unwell",
#     "Has a fever (high temperature) and a rash - Diabetes or is immunocompromised",
#     "Has had a seizure (convulsions, fitting), has never had febrile seizures (febrile convulsions)",
#     "Diarrhoea or vomiting, generally unwell",
#     "Possible child abuse",
#     "Infant under 3 months with fever",
#     "Pain in waves and/or bloody and slimy poo",
#     "Parents assess child as ill",
#     "Infant or child over 3 months with fever, does not seem weak and tired",
#     "Has a rash, otherwise fine",
#     "Pain over the cheeks, forehead or eyes",
#     "Has a fever (temperature), a cold, a sore throat, an earache or is coughing",
#     "Tummy ache (abdominal pain), otherwise fine",
#     "Stinging when peeing"
#   ],
#   "17 Bite / insect sting": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Sting in the throat, difficulty talking or swallowing",
#     "Alert, but decreasing consciousness",
#     "Pale, clammy skin (cold sweating)",
#     "Adder (viper) bite, feels unwell",
#     "Adder (viper) bite, high risk patient",
#     "Previous anaphylactic reaction to the same trigger",
#     "Anaphylactic reaction, rapidly getting worse",
#     "Major blood loss",
#     "Bitten more than 12 hours ago. Fever, generally unwell, significant deterioration",
#     "Insect sting in the throat, no other symptoms",
#     "Mild allergic reaction, getting worse",
#     "Adder / viper bite, light symptoms",
#     "Deep bite wound, anywhere on the body",
#     "Allergic reaction more than 30 mins after exposure",
#     "Bitten more than 12 hours ago. Fever and/or painful swelling in the",
#     "Reaction only in the affected area",
#     "Bite that barely punctures the skin",
#     "Tick bite",
#     "Animal bite in an area with rabies"
#   ],
#   "18 Bleeding - non-traumatic": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Alert, but decreasing consciousness",
#     "Pale, clammy skin (cold sweating), still bleeding",
#     "Coughing up large amounts of fresh blood",
#     "Vomiting large amounts of fresh blood",
#     "Vomiting dark blood similar to coffee grounds, seems weak and tired",
#     "Major rectal bleed",
#     "Large amount of black, tarry stools, feels unwell, sudden onset",
#     "Post-operative bleeding in the throat",
#     "Bleeding after an operation or an endoscopy",
#     "Vomiting small amounts of fresh blood",
#     "Vomiting dark blood, fine otherwise",
#     "Moderate rectal bleed without other symptoms",
#     "Large amount of black, tarry stools",
#     "Major nosebleed lasting more than 20 mins.",
#     "Coughing up small smounts of blood mixed with phlegm",
#     "Small amounts of blood on stools or on toilet paper",
#     "Black, tarry stools without other symptoms",
#     "Skin sores bleeding a little all the time"
#   ],
#   "19 Chest pain / cardiac disease": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Severe central chest pain lasting more than 5 minutes",
#     "Chest pain or discomfort in the chest - Alert, but decreasing consciousness",
#     "Chest pain or discomfort in the chest - Unwell, nauseous",
#     "Chest pain or discomfort in the chest - Pale, clammy skin (cold sweating)",
#     "Chest pain or discomfort in the chest - Pain radiating to the jaw, shoulder, arm or back",
#     "Chest pain or discomfort in the chest - Sudden weakness in the arms",
#     "Chest pain or discomfort in the chest - Brief effect from angina medication (GTN)",
#     "Chest pain or discomfort in the chest - Irregular or slow pulse, feels unwell",
#     "Chest pain or discomfort in the chest - Possible serious heart disease with unclear symptoms",
#     "Chest pain or discomfort in the chest - Two or more shocks from an ICD (implantable cardioverter defibrillator), no other symptoms",
#     "Moderate chest pain, no other symptoms",
#     "Irregular or slow pulse, no other symptoms",
#     "Lasting effect from 1-4 doses of angina medication (GTN spray or tablets)",
#     "Pain or discomfort at the side of the chest",
#     "One shock from an ICD (implantable cardioverter defibrillator), no other symptoms",
#     "Chest pain when breathing in deeply or with movement",
#     "Feeling of irregular heartbeat",
#     "Sudden palpitations, no other symptoms",
#     "Short, sharp pains in the chest",
#     "Anxious about heart disease"
#   ],
#   "20 Diabetes": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Is having a seizure (convulsion, fit)",
#     "Unwell and pain or discomfort in the chest, shoulder, arm or jaw",
#     "Restless and/or aggresssive, unable to drink",
#     "Pale, clammy skin (cold sweating), unable to drink",
#     "Drowsy (decreased level of consciousness) - May have a low blood sugar (hypo)",
#     "Drowsy (decreased level of consciousness) - May have a high blood sugar",
#     "Aggressive but able to drink or eat",
#     "Generally unwell - May have a low blood sugar (hypo)",
#     "Generally unwell - May have a high blood sugar",
#     "Generally unwell - Has a fever",
#     "Generally unwell - Producing a lot of urine recently",
#     "Generally unwell - Abdominal pain",
#     "Generally unwell - Has taken too much insulin, no other symptoms",
#     "Generally unwell - Pregnant with symptoms related to diabetes",
#     "Pale, cold and clammy skin, able to eat and/or drink",
#     "Restless, able to eat and/or drink",
#     "Fever, no other symptoms",
#     "Infection, no other symptoms",
#     "Has a high blood sugar",
#     "Has had a hypo, no other symptoms after taking sugary food / drink",
#     "Needs advice on regulating insulin, no other symptoms"
#   ],
#   "22 Fever / infection / sepsis": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "May have a fever (high temperature), generally very unwell: Drowsy (decreased level of consciousness)",
#     "May have a fever (high temperature), generally very unwell: Getting worse by the hour",
#     "May have a fever (high temperature), generally very unwell: Has a rash that doesn't fade when a glass is rolled over it",
#     "May have a fever (high temperature), generally very unwell: Has an intense headache, neck pain or neck stiffness",
#     "May have a fever (high temperature), generally very unwell: Light sensitivity",
#     "May have a fever (high temperature), generally very unwell: Hyperventilating",
#     "May have a fever (high temperature), generally very unwell: Difficulty swallowing",
#     "May have a fever (high temperature), generally very unwell: In a confused state, sudden onset",
#     "May have a fever (high temperature), generally very unwell: Seems cold, very weak and tired",
#     "May have a fever (high temperature), generally very unwell: Signs of infection within 48 hours of invasive medical treatment or examination",
#     "May have a fever (high temperature), generally very unwell: Excessive pain under the skin",
#     "May have a fever (high temperature), generally very unwell: Painful swelling, spreading rapidly",
#     "May have an infection and/or seems weak and tired: Confused and irritable",
#     "May have an infection and/or seems weak and tired: Rash",
#     "May have an infection and/or seems weak and tired: Very sore throat",
#     "May have an infection and/or seems weak and tired: Intense earache or frontal headache",
#     "May have an infection and/or seems weak and tired: Has or has had chills and shivering",
#     "May have an infection and/or seems weak and tired: Weakened immune system (immunocompromised), has a fever",
#     "May have an infection and/or seems weak and tired: Baby under 3 months with a fever",
#     "Child, generally unwell: Diarrhoea and / or vomiting",
#     "Child, generally unwell: Persistent cough",
#     "Has a fever, seems fine",
#     "Has a rash, seems fine",
#     "Hayfever, sore throat or cough, seems fine",
#     "Stinging when peeing"
#   ],
#   "23 Poisoning - not related to alcohol or drugs": [
#     "Unconscious (unresponsive)",
#     "May have ingested a potentially dangerous amount of a toxic substance - Is having a seizure (convulsion, fit)",
#     "May have ingested a potentially dangerous amount of a toxic substance - Serious or continuing (persistent, lasting) airway symptoms",
#     "May have ingested a potentially dangerous amount of a toxic substance - Pale, clammy skin (cold sweating)",
#     "May have ingested a potentially dangerous amount of a toxic substance - Difficulty swallowing",
#     "May have ingested a potentially dangerous amount of a toxic substance - The situation requires immediate treatment to avoid serious symptoms or injury. Assess the amount taken. In certain cases this could be a YELLOW response (urgent)",
#     "May have ingested a potentiallly dangerous amount of a toxic substance - Has swallowed a battery, eg. a button battery, has symptoms",
#     "May have ingested a potentiallly dangerous amount of a toxic substance - Has ingested a corrosive substance causing swallowing difficulties E.g. drain unblocker/cleaner, lye, caustic soda, strong acids",
#     "May have ingested a potentially dangerous amount of a toxic substance Assess the amount taken. In certain cases this could be a RED response (emergency)",
#     "May have ingested a corrosive substance, no airway symptoms, no hoarseness or difficulty swallowing E.g. drain unblocker/cleaner, lye, caustic soda, strong acids",
#     "Ingested an oil-based or petroleum product, no cough E.g. lighter fluid, white spirit, lamp oil, paraffin, petrol or diesel",
#     "Suspect self inflicted injury or neglect",
#     "May have ingested a small amount of a toxic substance, no symptoms"
#   ],
#   "24 Functional decline": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Pale, clammy skin (cold sweating)",
#     "Feels generally very unwell, onset within the last 24 hours",
#     "Feels ill and has no energy, sudden onset",
#     "Has fallen, may have a serious injury",
#     "Feels generally unwell, onset over the last 24 - 48 hours",
#     "Found on the floor or on the ground. Lacking further information, may have been lying there for a while",
#     "Altered level of consciousness and lack of awareness (suspect delirium), developing over the last 24-48 hours",
#     "Falling asleep during a consultation/check-up, possible emergency situation (suspect delirium), developing over the last 24-48 hours",
#     "Fall or found on the floor, now feeling better. May have an injury and/or can't explain what has happened",
#     "Increasing tendency to fall, developing over the last 24-48 hours",
#     "Dehydration or not getting enough fluids, feels generally unwell",
#     "Malnutrition or not eating enough, feels gernerally unwell",
#     "Unable to do everyday chores, gradual onset 48 hours or longer",
#     "Altered level of consciousness and lack of awareness, gradual onset 48 hours or longer",
#     "Falling asleep during a consultation/check-up, gradual onset 48 hours or longer",
#     "Increasing tendency to fall, gradual onset 48 hours or longer",
#     "Fall / found on the floor and can´t get up, no symptoms",
#     "Dehydration or not getting enough fluids, feels fine otherwise",
#     "Malnutrition or not eating enough, feels fine otherwise",
#     "Psychosocial problem - carers unavailable, Sudden functional decline must be kept separate from situations where the patient’s network fails, whilst s/he remains unchanged."
#   ],
#   "25 Childbirth": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Is having a seizure (convulsion, fitting)",
#     "Has been diagnosed with pre-eclampsia. Has a headache, disturbed vision or restlessness",
#     "Major bleeding",
#     "Less than 37 weeks pregnant - Persistent or severe pain or contractions",
#     "Less than 37 weeks pregnant - Waters have broken, contractions",
#     "Pain or contractions - Vaginal bleeding",
#     "Pain or contractions - Waters have broken",
#     "Pain or contractions - After a blow to the abdomen (after 20th week of pregnancy)",
#     "The baby is not in a normal position - Waters have broken",
#     "The baby is not in a normal position - Strong contractions",
#     "The baby is coming - The head is not presenting first (breech)",
#     "The baby is coming - Normal position (head first)",
#     "The baby is born - Very premature (before week 37)",
#     "The baby is born - Weak and not breathing normally",
#     "The baby is born - The mother is still bleeding profusely",
#     "Less than 37 weeks pregnant - Tightening or contractions, not continuous or strong",
#     "Less than 37 weeks pregnant - Waters have broken, no contractions",
#     "Less than 37 weeks pregnant - Some vaginal bleeding",
#     "Less than 37 weeks pregnant - The baby shows ittle or no activity",
#     "Full-term (week 37-40) - First time mother, less than 2 minutes between strong, regular contractions",
#     "Full-term (week 37-40) - Given birth previously, less that 5 minutes between strong, regular contractions",
#     "Full-term (week 37-40) - The baby is born, mother and baby seem to be fine.",
#     "Full-term (week 37-40) - First time mother, more than 2 minutes between contractions",
#     "Full-term (week 37-40) - Given birth previously, more than 5 minutes between contractions",
#     "Full-term (week 37-40) - Tightening or contracions, not regular or strong"
#   ],
#   "26 Gynecology / pregnancy": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Alert, but decreasing consciousness",
#     "Has been diagnosed with pre-eclampsia. Has a headache, disturbed vision or restlessness",
#     "Acute abdominal pain, pale, clammy skin (cold sweating)",
#     "Vaginal bleeding, pale, clammy skin (cold sweating)",
#     "Pregnant and - Having a fitting / convulsion / seizure",
#     "Pregnant and - Intense abdominal pain",
#     "Pregnant and - Contractions between weeks 20 and 36",
#     "Pregnant and - Significant vaginal bleeding",
#     "Pregnant and - Vaginal bleeding or abdominal pain after a blow to the stomach",
#     "Fever and pain and/or discomfort in the lower abdomen",
#     "Vaginal bleeding, significantly more than normal menstruation (period)",
#     "Acute abdominal pain, pregnancy cannot be ruled out",
#     "Miscarriage before week 20",
#     "Pregnant, over 20 weeks - Minor contractions or abdominal pain",
#     "Pregnant, over 20 weeks - Minor vaginal bleeding",
#     "Pregnant, over 20 weeks - Increasing headaches or blurring of vision",
#     "Pregnant, over 20 weeks - Anxious after a blow to the stomach",
#     "Pregnant, over 20 weeks - Generally unwell, fever and painful swelling in one breast",
#     "Pregnant, over 20 weeks - Unexpected intense pain, discomfort or bleeding after an induced abortion",
#     "Pregnant less than 20 weeks - Vaginal bleeding",
#     "Pregnant less than 20 weeks - Abdominal pain",
#     "Pregnant less than 20 weeks - Anxious after a blow to the stomach",
#     "Pregnant less than 20 weeks - Not pregnant. Abnormal pain or bleeding, no other symptoms"
#   ],
#   "27 Stroke symptoms": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Alert, but decreasing consciousness. Pale, clammy skin (cold sweating)",
#     "Sudden and continuing (persistent, lasting), This includes symptoms that improve and/or the patient had on waking up - Difficulty talking (slurred or garbled speech, babbling, looking for words)",
#     "Sudden and continuing (persistent, lasting), This includes symptoms that improve and/or the patient had on waking up - Difficulty smiling (face dropping to one side, asymmetrical face)",
#     "Sudden and continuing (persistent, lasting), This includes symptoms that improve and/or the patient had on waking up - Dificulty lifting or holding up an arm or a leg, or weakness (paralysis) on one side",
#     "Sudden and continuing (persistent, lasting), This includes symptoms that improve and/or the patient had on waking up - Loss of sensation (feeling) when touched (stroked) on an arm, leg or face and arm",
#     "Sudden and continuing (persistent, lasting), This includes symptoms that improve and/or the patient had on waking up - Changes in vision (blurred vision, double vision or loss of vision in one eye)",
#     "Sudden and continuing (persistent, lasting), This includes symptoms that improve and/or the patient had on waking up - Dizziness, unsteadiness, confusion, disorientation, difficulty controlling movement of an arm and/or leg",
#     "Sudden and continuing (persistent, lasting), This includes symptoms that improve and/or the patient had on waking up - Atypical and intense headache",
#     "Has just experienced possible stroke symptoms, no symptoms now. If symptoms occur repeatedly: Check info PAY SPECIAL ATTENTION TO",
#     "Repeated dizzy spells, stroke unlikely"
#   ],
#   "28 Headache": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Seizure (fitting / convulsions)",
#     "Sudden atypical and intense headache - Pale, clammy skin (cold sweating)",
#     "Sudden atypical and intense headache - Nauseous",
#     "Sudden atypical and intense headache - Paralysis or numbness",
#     "Sudden atypical and intense headache - Difficulty talking",
#     "Sudden atypical and intense headache - Altered level of consciousness",
#     "Sudden atypical and intense headache - Light sensitivity or changes in vision (blurred vision, double vision or loss of vision in one eye)",
#     "Sudden atypical and intense headache - Headache and in a confused state all of a sudden",
#     "Seems hot (febrile) - Feels generally unwell, has an intense headache, neck pain or neck stiffness",
#     "Seems hot (febrile) - Has a spotty rash that doesn’t fade when a glass is rolled over it",
#     "Abnormal, intense headache, no other symptoms",
#     "Blow to the head, is on anticoagulants",
#     "Blow to the head within the last 24 hours, increasing headache",
#     "Pregnant with atypical and increasingly intense headache",
#     "Has had brain surgery, increasingly intense headache",
#     "Blow to the head more than 24 hours ago, increasing headache",
#     "Suffers from migraine, attack now",
#     "Has just taken angina medication (GTN)",
#     "Frontal headache, fever and blocked nose",
#     "Headache, no other symptoms"
#   ],
#   "29 Skin / rash": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Has a spotty rash that don't fade when a glass is rolled over it",
#     "Has a rash and - Drowsy (decreased level of consciousness). Pale, clammy skin (cold sweating)",
#     "Has a rash and - May be febrile, deteriorating by the hour",
#     "Has a rash and - May be febrile, generally unwell",
#     "Has a rash and - Intense headache, neck pain or neck stiffness",
#     "Has a rash and - Fever and intense pain deep under the skin",
#     "Has a rash and - Painful swelling that is spreading fast",
#     "Has a rash and - Allergic rash, rapid deterioration (has reacted to the same trigger earlier)",
#     "Seems gererally unwell, has a rash",
#     "Rash covering much of the body",
#     "Itchy rash, feels unwell",
#     "Fever and painful swelling in or under the skin",
#     "Pain under the skin, unclear cause",
#     "Rash over a limited area of the skin",
#     "Rash, seems fine",
#     "Chronic skin condition or rash",
#     "Itchy rash",
#     "May have lice or scabies",
#     "Rash and/or sore on or near the genitals"
#   ],
#   "30 Hyperthermia / heat stroke / heat exhaustion": [
#     "Possible hyperthermia (heatstroke) or has been exposed to extreme heat - Unconscious (unresponsive)",
#     "Possible hyperthermia (heatstroke) or has been exposed to extreme heat - Shortness of breath or difficulty breathing",
#     "Possible hyperthermia (heatstroke) or has been exposed to extreme heat - Seizure (convulsions, fit)",
#     "Possible hyperthermia (heatstroke) or has been exposed to extreme heat - Drowsy (decreased level of consciousness)",
#     "Possible hyperthermia (heatstroke) or has been exposed to extreme heat - Completely passive (uninterested, complacent, detatched)",
#     "Possible hyperthermia (heatstroke) or has been exposed to extreme heat - Weak and tired after abnormal and/or demanding physical exercise",
#     "Possible hyperthermia (heatstroke) or has been exposed to extreme heat - Has taken drugs",
#     "Possible hyperthermia (heatstroke) or has been exposed to extreme heat - Very rapid pulse",
#     "Exposed to extreme heat - Very dizzy",
#     "Exposed to extreme heat - Weak and tired",
#     "Exposed to extreme heat - Unwell",
#     "Exposed to extreme heat - Headache",
#     "Exposed to extreme heat - Rapid pulse",
#     "Exposure to extreme heat, no other symptoms",
#     "Prolonged exertion in a hot climate and muscle cramps"
#   ],
#   "31 Hypothermia / cold person": [
#     "Seems to have a low body temperature - Unconscious (unresponsive)",
#     "Seems to have a low body temperature - Shortness of breath or difficulty breathing",
#     "Seems to have a low body temperature - Drowsy (decreased level of consciousness)",
#     "Seems to have a low body temperature - Very passive (disinterested, detatched)",
#     "Seems to have a low body temperature - Has additional major injury",
#     "Seems to have a low body temperature - Helpless and in danger of becoming even colder",
#     "Seems to have a low body temperature - Is weak and/or worn out (exhausted, tired)",
#     "Seems to have a low body temperature, repsonsive and no other symptoms",
#     "May have deep or severe frostbite (hard, stiffened skin with loss of sensation)",
#     "Has been very cold, body temperature measures ca.36-35 ºC, no other symptoms",
#     "May have superficial frostbite (painful skin, but remains soft)",
#     "Has been exposed to extreme cold, no other symptoms"
#   ],
#   "32 Seizures (convulsions, fits)": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Ongoing seizure (convulsions, fitting), not known to have epilepsy",
#     "Has had a seizure (convulsions, fit) - Lasting more than 5 minutes",
#     "Has had a seizure (convulsions, fit) - Several seizures one after the other without waking up",
#     "Has had a seizure (convulsions, fit) - Cannot be roused, the seizure ended more than 20 minutes ago",
#     "Has had a seizure (convulsions, fit) - Is pregnant",
#     "Has had a seizure (convulsions, fit) - Is a diabetic",
#     "Has had a seizure (convulsions, fit) - Recent injury to the head",
#     "Has had a seizure (convulsions, fit) - Is warm, has a spotty rash that doesn’t fade when a glass is rolled over it",
#     "Ongoing convulsions, has epilepsy",
#     "Has had a seizure (convulsions, fit) - Infant or small child, may have a fever, has never had febrile seizures (febrile convulsions)",
#     "Has had a seizure (convulsions, fit) - The seizure lasted less than 5 minutes",
#     "Has had a seizure (convulsions, fit) - Has drunk a lot of alcohol recently",
#     "Has had a seizure (convulsions, fit) - Has epilepsy, still unconscious (unresponsive)",
#     "Has had a seizure (convulsions, fit) - Still drowsy (decreased level of consciousness) and/or confused after more than 20 minutes",
#     "Has had a seizure (convulsions, fit) - Spasms in one part of the body (arm or leg), drowsy (decreased level of consciousness) and/or confused",
#     "Infant or small child, has had a seizure (convulsions / fit). May have a fever, has had febrile convulsions earlier",
#     "Has epilepsy. Has had a seizure (convulsions, fit), gradually regaining consciousness",
#     "Spasms in one part of the body (arm eller leg). Fully alert"
#   ],
#   "33 Breathing problems": [
#     "Unconscious (unresponsive)",
#     "Alert, but decreasing consciousness",
#     "Significant difficulty breathing, Check info SIGNIFICANT BREATHING PROBLEMS",
#     "Drowsy (decreased level of consciousness), new situation with confusion and/or vagueness, Check info NEW EMERGED CONFUSION",
#     "Pale, clammy skin (cold sweating)",
#     "Pain or discomfort in the chest",
#     "Gurgling in the chest, frothy spit",
#     "Unable to swallow spit, dribbling",
#     "Has a known lung condition (illness)",
#     "Injured patient with shortness of breath or difficulty breathing",
#     "Moderate breathing problems, Check info MODERATE BREATHING DIFFICULTIES",
#     "Health worker reporting a category yellow respiratory rate, Check the table RESPIRATORY RATE",
#     "Has a lung condition (illness), is worried it might be getting worse",
#     "Coughing non-stop, seems weak and tired",
#     "Young person with rapid breathing, a feeling of not gettting enough air. Anxiety, tingling around the mouth, in the fingers. Non-risk patient, seems well, simple measures are not helping",
#     "Slight difficulty breathing, Check info MILD BREATHING DIFFICULTIES",
#     "Health worker reporting a category green respiratory rate, Check the table RESPIRATORY RATE",
#     "Light symptoms related to breathing",
#     "Has has panic attacks and/or hyperventilated earlier, the patient is easily calmed during the call and is being taken care of"
#   ],
#   "34 Drug abuse / intoxication / overdose": [
#     "Unconscious (unresponsive)",
#     "Is having a conviulsion / fit / seizure",
#     "Barely breathing (weak breathing, slow breathing)",
#     "Pale, clammy skin (cold sweating)",
#     "Has taken central nervous system stimulants, unwell or extremely hot e.g. cocaine, amphetamines, ecstacy",
#     "Has taken a large number of pills or other intoxicant, difficult to rouse",
#     "Intoxicated or drunk and may be seriously injured",
#     "Can't see properly, may have ingested methanol",
#     "Major risk of serious violence",
#     "May have taken an overdose, breathing normally. The severity depends on the amount of pills / medication / drugs, time and symptoms",
#     "Has taken a large number of pills, easy to rouse when stimulated. The severity depends on the amount of pills / medication / drugs, time and symptoms",
#     "Seems intoxicated (drunk, not sober, inebriated), difficult to rouse",
#     "Has had a seizure (convulsion, fit) lasting less than 5 minutes",
#     "May have methanol poisoning. Vision normal.",
#     "Agitated and out of control",
#     "Agressive and threatening violence",
#     "Threatening to take an overdose",
#     "Severely depressed, asking to talk to a doctor or to others who can help",
#     "Intoxicated (drunk), unable to take care of him/herself",
#     "Wants help with a drug or alcohol problem",
#     "Wants to talk to a doctor",
#     "Anxious or unwell after intoxication",
#     "Alcohol intoxication, no other medical problems"
#   ],
#   "35 Pain in the abdomen / back / extremities": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Acute abdominal pain. Alert, but decreasing consciousness",
#     "Acute back pain. Alert, but decreasing consciousness",
#     "Acute pain. Pale, clammy skin (cold sweating)",
#     "Severe abdominal pain, seems weak and tired, or is generally unwell",
#     "Vomiting large amounts of fresh blood",
#     "Vomiting dark blood resembling coffee grounds, seems weak and tired",
#     "Acute pain occurring suddenly in the arms or legs",
#     "Persistent abdominal pain, feels unwell",
#     "Fever and increasingly strong abdominal pain",
#     "Severe persistent pain in the groin",
#     "Severe pain coming in waves, in the abdomen, lower back or side",
#     "Vomiting or diarrhoea, is generally unwell",
#     "Vomiting dark blood, fine otherwise",
#     "Severe pain in the lower abdomen, could be pregnant",
#     "Severe back pain",
#     "Back pain - Numbness in the leg or foot",
#     "Back pain - Difficulty passing urine (peeing)",
#     "Back pain - Fever, increasing pain in the side or back",
#     "Back pain - Moderate pain in the arms or legs",
#     "Diarrhoea or vomiting, otherwise well",
#     "Abdominal pain, no other symptoms",
#     "Back pain, no other symptoms",
#     "Unable to expel gas / cannot pass stools (poo)",
#     "Slight pain in the arms or legs"
#   ],
#   "36 Uncertain / unidentified problem": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Alert, but decreasing consciousness",
#     "Pale, clammy skin (cold sweating), sudden onset",
#     "Significantly weak, generally unwell, sudden onset",
#     "Unwell and very frail, sudden onset",
#     "Unclear signs of illness within 48 hours after invasive medical treament or examination",
#     "Possible critical / serious problem (more information not readily available)",
#     "Difficulty communicationg, may have a serious health problem",
#     "Exhausted or worn out (uncertain or unclear information)",
#     "Loss of consciousness (fainted) more than once",
#     "Repeated calls, unclear problem",
#     "May have an urgent problem (more information not readily available)",
#     "May have an urgent problem (nothing applicable in NINM)",
#     "Psychosocial problem",
#     "Assume non-urgent problem (more information not readily available)",
#     "Assume non-urgent problem (nothing applicable in NINM)"
#   ],
#   "37 Urinary tract": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Has a urinary tract infection (UTI), possible fever. Pale, clammy skin (cold sweating)",
#     "Generally very unwell, intense pain",
#     "Severe pain coming in waves, in the abdomen or lower back",
#     "Fever and severe pain in the back",
#     "Sudden, severe pain on one side of the scrotum and in the lower abdomen. May have nausea and vomiting too",
#     "Stinging when peeing, may have a fever. Change in general condition",
#     "Severe pain in the lower abdomen and difficulty peeing",
#     "Increasing pain in the scrotum or groin",
#     "Kidney transplant patient with fever and pain or producing small amounts of urine",
#     "Persistent erection, severe or moderate pain",
#     "Stinging or pain when peeing",
#     "Discharge (pus) from the penis",
#     "Blood in the urine",
#     "Difficulty peeing",
#     "Frequent peeing",
#     "Swelling or lump in the groin, no pain",
#     "Sore on or by the genitals"
#   ],
#   "38 Ear, nose and throat": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Major bleeding from the nose or throat. Pale, clammy skin (cold sweating)",
#     "Swallowed a button battery",
#     "Possible fever, difficulty swallowing",
#     "Bleeding after a throat operation",
#     "Child persistently coughing, generally unwell",
#     "Very sore throat, generally unwell",
#     "Obstruction in the throat, breathing normally",
#     "Major nosebleed, lasting more than 20 minutes",
#     "Suddenly dizzy and unwell, stroke or TIA not suspected",
#     "Sudden reduced hearing and dizzy without any clear reason",
#     "Post-operative bleeding in the throat, bleeding has stopped",
#     "Pain over the cheeks, forehead or eyes. Worsens when bending forwards",
#     "Possible broken nose",
#     "Cold, sore throat or cough, seems fine otherwise",
#     "Earache",
#     "Discharge from the ear, has an ear infection",
#     "Has a foreign object in the ear canal",
#     "Has a foreign object in the nose",
#     "Nosebleed lasting less than 20 minutes",
#     "Dizzy spells",
#     "Toothache"
#   ],
#   "39 Eye": [
#     "Unconscious (unresponsive)",
#     "Shortness of breath or difficulty breathing",
#     "Sudden blurring of vision. Alert, but decreasing consciousness",
#     "Sudden vision loss, blurred vision, double vision or loss of vision in one eye",
#     "Sudden, extreme pain and blurring of vision in one eye, nausea and retching",
#     "Major injury in, or close to, the eye",
#     "Blow to the eye. Drowsy (decreased level of consciousness)",
#     "Major corrosive injury in, or close to, the eye",
#     "Can't see properly. May have drunk methanol",
#     "Severe, persistent pain in or close to the eye, feels unwell",
#     "Deteriorating vision in one or both eyes over the last few days",
#     "Minor corrosive injury in or close to the eye",
#     "Dark circles / bruising around both eyes after a head injury",
#     "Normal vision, may have drunk methanol",
#     "Red, painful and irritated eye",
#     "Stinging or painful rash round one eye",
#     "Severe, persistent pain in or around the eye, no other symptoms",
#     "Foreign object stuck in the eye",
#     "Red and irritated eye, no pain",
#     "Red eye, no irritation or pain",
#     "Has been exposed to strong sun. Pain and cannot see properly",
#     "Has been welding. Pain and cannot see properly",
#     "Black eye (bruising), no other symptoms"
#   ]
# }

# %% [markdown]
# ### Generate criteria advice pairs

# %%
fp_json = ["Data/Json/Unique_Criteria/" + file for file in os.listdir("Data/Json/Unique_Criteria")]
fp_json.sort()

# Resolve end index if negative
resolved_end = len(fp_json) + end_index if end_index < 0 else end_index
indices = [i for i in range(start_index, resolved_end) if i not in exclude.tolist()]
fp_json = [fp_json[i] for i in indices]


criteria_advice_mapping = defaultdict(list)
for file_path in fp_json:
	with open(file_path, "r", encoding="utf-8") as f:
		for line in f:
			entry = json.loads(line.strip()) 
			if not entry:
				continue

			data = entry["entry"]

			criteria = data[0]["content"]
			chapter = data[1]["content"]
			advices = data[1]["advices"]

			criteria_advice_mapping[chapter].append({
				"criteria": criteria,
				"advices": advices
			})

print(json.dumps(criteria_advice_mapping, indent=2, ensure_ascii=False))
# Out:
# {
#   "03 Unconscious / decreased level of consciousness, breathing normally": [
#     {
#       "criteria": "Unconscious adult, breathing normally",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times."
#       ]
#     },
#     {
#       "criteria": "Unconscious child, breathing normally",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times."
#       ]
#     },
#     {
#       "criteria": "Drowsy (decreased level of consciousness), breathing normally",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (ALTERED LEVEL OF CONSCIOUSNESS)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area."
#       ]
#     },
#     {
#       "criteria": "Has had a seizure (convulsions, fit), drowsy (decreased level of consciousness) and/or confused after 20 minutes",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (ALTERED LEVEL OF CONSCIOUSNESS)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area.",
#         "\nCONVULSIONS - WHEN THE CONVULSIONS STOP\n- Make sure the airway is free and the person is breathing normally.\n- Lay the person on his / her side.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area."
#       ]
#     },
#     {
#       "criteria": "Loss of consciousness (fainting) more than once, alert now",
#       "advices": [
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (ALTERED LEVEL OF CONSCIOUSNESS)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area.",
#         "\nIF THE PERSON FEELS FAINT\n- Lay the person flat on his / her back."
#       ]
#     },
#     {
#       "criteria": "Temporary loss of consciousness (fainting, passing out)",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Temporary loss of consciousness (fainting, passing out) after taking GTN",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Has epilepsy. Gradually waking up after a seizure (convulsion, fit)",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     }
#   ],
#   "04 Choking / foreign object": [
#     {
#       "criteria": "May have an airway blockage, unconscious or losing consciousness",
#       "advices": [
#         "\nSITUATIONAL GUIDANCE\n- Help is on the way as I speak to you.\n- You must help the person get the object out. I will tell you what to do.\n- Put the phone on speaker if you can.\n- How old is the person?\n- Is s/he able to cough?\n- If the answer is yes - get him / her to keep coughing until the object comes out.\n- Help him / her to find a comfortable position. Let me know if s/he is unable to cough any more."
#       ]
#     },
#     {
#       "criteria": "May have an airway blockage, difficulty breathing",
#       "advices": [
#         "\nSITUATIONAL GUIDANCE\n- Help is on the way as I speak to you.\n- You must help the person get the object out. I will tell you what to do.\n- Put the phone on speaker if you can.\n- How old is the person?\n- Is s/he able to cough?\n- If the answer is yes - get him / her to keep coughing until the object comes out.\n- Help him / her to find a comfortable position. Let me know if s/he is unable to cough any more."
#       ]
#     },
#     {
#       "criteria": "May have a battery in the airway or throat",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way! Keep this phone free until the medics arrive.\n- Keep an eye on the person all the time.Callback immediately if there is any change.\n- Don't give the person anything to eat or drink until the situation is clear.",
#         "\nSWALLOWED A BUTTON BATTERY\n- Don't try to make the person sick.\n- Don't give him/her any food, drink or activated charcoa"
#       ]
#     },
#     {
#       "criteria": "Alert, symptoms showing possible blockage in airway or throat",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way! Keep this phone free until the medics arrive.\n- Keep an eye on the person all the time.Callback immediately if there is any change.\n- Don't give the person anything to eat or drink until the situation is clear.",
#         "\nIF THE PERSON IS AWAKE / ALERT\n- Get the person to cough for as long as s/he is able.\n- A blockage in the throat will usually trigger a coughing reflex. Coughing can solve the problem and the object will dislodge and come up.\n- CHILDREN: Do not put your fingers in the child's mouth. Check if you can see the object and only remove the blockage if you can see it."
#       ]
#     },
#     {
#       "criteria": "Suspect a button battery in the ear or nose",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way! Keep this phone free until the medics arrive.\n- Keep an eye on the person all the time.Callback immediately if there is any change.\n- Don't give the person anything to eat or drink until the situation is clear."
#       ]
#     },
#     {
#       "criteria": "Coughed up the object, no symptoms now",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Suspect a possible object in airway or throat, after a few days",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Suspect an object in one of the body's orifices",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     }
#   ],
#   "05 Mental health issue": [
#     {
#       "criteria": "Sudden change in state of mind, very restless (troubled, agitated). In immediate or imminent danger to self or others",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Let me know immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Sudden change in state of mind, aggressive, threatening behaviour. In immediate or imminent danger to self or others",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Let me know immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Increasing anxiety",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Increasing restlessness and/or confusion",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Visual and/or auditory (hearing) hallucinations",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Verbal threats",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Threat of violence",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Indifferent (disinterested) or major mood swings",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Caller needs assistance",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Change in behaviour or mood, does not have a known mental health problem",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Known mental health issue, several calls, probably needs medical assistance",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person.\n- Do not put yourself or others in any danger.\n- Let me know if anything changes.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Report of concern. Behaving strangely, but is quiet and under control",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Feeling low and inert (listless)",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Wants to talk to a doctor or others who can help",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Change in state of mind and/or deterioration in already known mental health issue with: Frequent caller without any new problems, known mental health issue",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     }
#   ],
#   "06 Mental health crisis - suicide risk": [
#     {
#       "criteria": "Unconscious (unresponsive)",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed."
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: Hanging",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing. If the person can't sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards.",
#         "\nHANGING\n- If there is any hope of saving the person:\n- Try to remove the constriction by cutting it. Start CPR immediately.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)"
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: Involving a dangerous amount of medication or other toxic substance",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)"
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: Involving a weapon",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)"
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: jumping from a heigh",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)"
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: drowning",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)"
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: Deep cuts and major blood loss",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)"
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: Involving gases or carbon monoxide",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nCARBON MONOXIDE POISONING\n- Get the person out into the fresh air immediately. Do not put yourself in any danger."
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: Involving other method of injury or other damaging situation",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person Do not put yourself or others in any danger."
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: Serious risk of suicide and immediately available method. Has concrete plans and is well prepared",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person Do not put yourself or others in any danger."
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: Immediate risk of suicide after assessment",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)",
#         "\nRESTLESS / AGGRESSIVE PERSON\n- Try to help and calm the person Do not put yourself or others in any danger."
#       ]
#     },
#     {
#       "criteria": "Serious suicide attempt: Report of concern, acute risk of suicide If risk factors are present - assess suicide risk",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY\n- Get yourself to a safe place if necessary.\n- Keep me informed.",
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)",
#         "\nFOCUS ON THE PERSON'S ABILITY / STRATEGY FOR COPING\n- Encourage the person to use his / her own mechanism / strategy for coping."
#       ]
#     },
#     {
#       "criteria": "Risk of suicide: Self-harm, minor injury or poisoning. Alert and breathing normally",
#       "advices": [
#         "\nSELF-HARMING\n- We must assess whether you need treatment, and if so, when.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Risk of suicide: May have taken toxic substances, not in immediate need of an ambulance",
#       "advices": [
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nFOCUS ON THE PERSON'S ABILITY / STRATEGY FOR COPING\n- Encourage the person to use his / her own mechanism / strategy for coping.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Risk of suicide: Injury, not in immediate need of an ambulance",
#       "advices": [
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nFOCUS ON THE PERSON'S ABILITY / STRATEGY FOR COPING\n- Encourage the person to use his / her own mechanism / strategy for coping.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Risk of suicide: Has a self-harm problem, minor injuries due to self-harm and/or feels the need to self-harm",
#       "advices": [
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)",
#         "\nSELF-HARMING\n- We must assess whether you need treatment, and if so, when.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Risk of suicide: Wants to talk to a doctor or others who can help. Feels depressed or has suicidal thoughts",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nFOCUS ON THE PERSON'S ABILITY / STRATEGY FOR COPING\n- Encourage the person to use his / her own mechanism / strategy for coping.",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Risk of suicide:  Report of concern, assessed to be less serious",
#       "advices": [
#         "\nSUICIDE THREATS\n- Try to help and calm the person, but only if you are not putting yourself in any danger.\n- Put the person in touch with a doctor or someone else s/he wishes to contact (crisis intervention, crisis assistance, priest, other)",
#         "\nIF RELEVANT:\n- There is a free helpline for mental health issues: 116 123 that you can call at any time. You do not need to tell them your name if you wish to remain anonymous."
#       ]
#     },
#     {
#       "criteria": "Risk of suicide: Report of concern related to a patient with suicidal thoughts",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Risk of suicide: Feeling low and inert (listless)",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Risk of suicide: Wants to talk to a doctor or others who can help",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     }
#   ],
#   "07 Burns": [
#     {
#       "criteria": "Unconscious (unresponsive)",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can."
#       ]
#     },
#     {
#       "criteria": "Shortness of breath or difficulty breathing",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing. If the person can't sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards. \n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change."
#       ]
#     },
#     {
#       "criteria": "May have a serious injury due to fire, smoke, scalding or electricity",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing. If the person can't sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards. \n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change.",
#         "\nFIRST AID FOR SKIN BURNS\n- Cool the affected area with tepid water (20 degrees) for at least 20 minutes. Do not use ice to cool the skin.\n- Avoid over-cooling, the person must not get cold.\n- Remove clothing and jewelry, but do not remove clothes that are stuck to the skin.\n- Cover the injured area with plastic wrap / glad pack, or with the cleanest material you have at hand (compresses, bandages, textiles)\n- The injured area should be elevated if possible.\n- Use a burns dressing (bandage) if available."
#       ]
#     },
#     {
#       "criteria": "Exposed to smoke or toxic gases from a fire: Drowsy (decreased level of consciousness), confused and/or irritable",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing. If the person can't sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards. \n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area."
#       ]
#     },
#     {
#       "criteria": "Exposed to smoke or toxic gases from a fire: Difficulty talking, swallowing, coughing or is hoarse",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing. If the person can't sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards. \n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area."
#       ]
#     },
#     {
#       "criteria": "Exposed to smoke or toxic gases from a fire: Soot particles in the nose, mouth or spit",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing. If the person can't sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards. \n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area."
#       ]
#     },
#     {
#       "criteria": "Serious burns injury or full thickness burns: Child",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nFIRST AID FOR SKIN BURNS\n- Cool the affected area with tepid water (20 degrees) for at least 20 minutes. Do not use ice to cool the skin.\n- Avoid over-cooling, the person must not get cold.\n- Remove clothing and jewelry, but do not remove clothes that are stuck to the skin.\n- Cover the injured area with plastic wrap / glad pack, or with the cleanest material you have at hand (compresses, bandages, textiles)\n- The injured area should be elevated if possible.\n- Use a burns dressing (bandage) if available."
#       ]
#     },
#     {
#       "criteria": "Serious burns injury or full thickness burns: Adult",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nFIRST AID FOR SKIN BURNS\n- Cool the affected area with tepid water (20 degrees) for at least 20 minutes. Do not use ice to cool the skin.\n- Avoid over-cooling, the person must not get cold.\n- Remove clothing and jewelry, but do not remove clothes that are stuck to the skin.\n- Cover the injured area with plastic wrap / glad pack, or with the cleanest material you have at hand (compresses, bandages, textiles)\n- The injured area should be elevated if possible.\n- Use a burns dressing (bandage) if available."
#       ]
#     },
#     {
#       "criteria": "Serious burns injury or full thickness burns: Over 65 years",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nFIRST AID FOR SKIN BURNS\n- Cool the affected area with tepid water (20 degrees) for at least 20 minutes. Do not use ice to cool the skin.\n- Avoid over-cooling, the person must not get cold.\n- Remove clothing and jewelry, but do not remove clothes that are stuck to the skin.\n- Cover the injured area with plastic wrap / glad pack, or with the cleanest material you have at hand (compresses, bandages, textiles)\n- The injured area should be elevated if possible.\n- Use a burns dressing (bandage) if available."
#       ]
#     },
#     {
#       "criteria": "injury or full thickness burns in the face, hands or genitals",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nFIRST AID FOR SKIN BURNS\n- Cool the affected area with tepid water (20 degrees) for at least 20 minutes. Do not use ice to cool the skin.\n- Avoid over-cooling, the person must not get cold.\n- Remove clothing and jewelry, but do not remove clothes that are stuck to the skin.\n- Cover the injured area with plastic wrap / glad pack, or with the cleanest material you have at hand (compresses, bandages, textiles)\n- The injured area should be elevated if possible.\n- Use a burns dressing (bandage) if available."
#       ]
#     },
#     {
#       "criteria": "Injury due to high voltage electric current or lightning",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nHIGH VOLTAGE CURRENT\n- Turn off the electricity if possible.\n- Fires emitting many dangerous gases often occur with high voltage accidents. Be aware that the person can develop swelling in the airways - this can happen suddenly or gradually after exposure.\n- All high voltage cabinets provide an insulated pole, this should be used to push the injured person out of danger.\n- Do not touch the casualty if s/he is in contact with the electrical source.\n- Keep everyone away from anything that can conduct the electrical current.\n- Is there an AED (defibrillator) at hand? Get someone to fetch it."
#       ]
#     },
#     {
#       "criteria": "Other serious or extensive injury in addition to burns",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nFIRST AID FOR SKIN BURNS\n- Cool the affected area with tepid water (20 degrees) for at least 20 minutes. Do not use ice to cool the skin.\n- Avoid over-cooling, the person must not get cold.\n- Remove clothing and jewelry, but do not remove clothes that are stuck to the skin.\n- Cover the injured area with plastic wrap / glad pack, or with the cleanest material you have at hand (compresses, bandages, textiles)\n- The injured area should be elevated if possible.\n- Use a burns dressing (bandage) if available."
#       ]
#     },
#     {
#       "criteria": "Serious burns injury or full thickness burns after exposure to chemicals",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nFIRST AID FOR SKIN BURNS\n- Cool the affected area with tepid water (20 degrees) for at least 20 minutes. Do not use ice to cool the skin.\n- Avoid over-cooling, the person must not get cold.\n- Remove clothing and jewelry, but do not remove clothes that are stuck to the skin.\n- Cover the injured area with plastic wrap / glad pack, or with the cleanest material you have at hand (compresses, bandages, textiles)\n- The injured area should be elevated if possible.\n- Use a burns dressing (bandage) if available."
#       ]
#     },
#     {
#       "criteria": "Missing persons in connection with a fire",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can."
#       ]
#     },
#     {
#       "criteria": "Fall from a height and electricity passing through the body at the same time",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nSAFETY AT THE SCENE\n- Keep out of danger and always ensure the safety of others.\n- If possible and without risk, get all casualties to safety.\n- Try to get an overall picture and give me more information as soon as you can.",
#         "\nHIGH VOLTAGE CURRENT\n- Turn off the electricity if possible.\n- Fires emitting many dangerous gases often occur with high voltage accidents. Be aware that the person can develop swelling in the airways - this can happen suddenly or gradually after exposure.\n- All high voltage cabinets provide an insulated pole, this should be used to push the injured person out of danger.\n- Do not touch the casualty if s/he is in contact with the electrical source.\n- Keep everyone away from anything that can conduct the electrical current.\n- Is there an AED (defibrillator) at hand? Get someone to fetch it.",
#         "\nLOW VOLTAGE CURRENT (DOMESTIC ELECTRICITY 230V)\n- Turn off the electricity if possible.\n- Try to get the casualty away from the electrical current - use a broom handle or pull the clothes - but take care - think own safety first.\n- Is there an AED (defibrillator) at hand? Get someone to fetch it.\n- NB! There is a risk of arrhythmia (irregular heartbeat).\n- If the person feels unwell, s/he should go to hospital for a check.\n- Even if the person feels fine, s/he should be checked by a doctor."
#       ]
#     },
#     {
#       "criteria": "Low voltage current (230V) and has been stuck to the source",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
# ...
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing.\n\nIf the person can’t sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards.\n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change."
#       ]
#     },
#     {
#       "criteria": "Has a urinary tract infection (UTI), possible fever. Pale, clammy skin (cold sweating)",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area.",
#         "\nPOSSIBLE URINARY TRACT INFECTION (UTI)\n- Intense pain or pain in waves in the back or lower back, is often due to a UTI.\n- Try to get a urine sample in a clean glass. Keep the sample in the fridge until it can be checked.\n- Try to empty the bladder completely every time you pee.\n- Do not delay if the bladder is full.\n- Treatment with antibiotics may be necessary."
#       ]
#     },
#     {
#       "criteria": "Generally very unwell, intense pain",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area.",
#         "\nPOSSIBLE URINARY TRACT INFECTION (UTI)\n- Intense pain or pain in waves in the back or lower back, is often due to a UTI.\n- Try to get a urine sample in a clean glass. Keep the sample in the fridge until it can be checked.\n- Try to empty the bladder completely every time you pee.\n- Do not delay if the bladder is full.\n- Treatment with antibiotics may be necessary."
#       ]
#     },
#     {
#       "criteria": "Severe pain coming in waves, in the abdomen or lower back",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nPOSSIBLE KIDNEY STONE\n- Do not drink while you are in pain.\n- Strong painkillers are often necessary if this is a kidney stone.\n- It often helps to drink large amounts, once the pain is over."
#       ]
#     },
#     {
#       "criteria": "Fever and severe pain in the back",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nPOSSIBLE URINARY TRACT INFECTION (UTI)\n- Intense pain or pain in waves in the back or lower back, is often due to a UTI.\n- Try to get a urine sample in a clean glass. Keep the sample in the fridge until it can be checked.\n- Try to empty the bladder completely every time you pee.\n- Do not delay if the bladder is full.\n- Treatment with antibiotics may be necessary."
#       ]
#     },
#     {
#       "criteria": "Sudden, severe pain on one side of the scrotum and in the lower abdomen. May have nausea and vomiting too",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times."
#       ]
#     },
#     {
#       "criteria": "Stinging when peeing, may have a fever. Change in general condition",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nPOSSIBLE URINARY TRACT INFECTION (UTI)\n- Intense pain or pain in waves in the back or lower back, is often due to a UTI.\n- Try to get a urine sample in a clean glass. Keep the sample in the fridge until it can be checked.\n- Try to empty the bladder completely every time you pee.\n- Do not delay if the bladder is full.\n- Treatment with antibiotics may be necessary."
#       ]
#     },
#     {
#       "criteria": "Severe pain in the lower abdomen and difficulty peeing",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nPOSSIBLE URINARY TRACT INFECTION (UTI)\n- Intense pain or pain in waves in the back or lower back, is often due to a UTI.\n- Try to get a urine sample in a clean glass. Keep the sample in the fridge until it can be checked.\n- Try to empty the bladder completely every time you pee.\n- Do not delay if the bladder is full.\n- Treatment with antibiotics may be necessary."
#       ]
#     },
#     {
#       "criteria": "Increasing pain in the scrotum or groin",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times."
#       ]
#     },
#     {
#       "criteria": "Kidney transplant patient with fever and pain or producing small amounts of urine",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times."
#       ]
#     },
#     {
#       "criteria": "Persistent erection, severe or moderate pain",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nCONTINUING PAINFUL ERECTION\n- May be treated by cooling down the penis with cold water, a cold shower or with ice packs.\n- If the complaint lasts more than 3 to 4 hours, it may be necessary to get it treated.\n- Seek medical advice (116 117 or phone your GP)"
#       ]
#     },
#     {
#       "criteria": "Stinging or pain when peeing",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Discharge (pus) from the penis",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Blood in the urine",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Difficulty peeing",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Frequent peeing",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Swelling or lump in the groin, no pain",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Sore on or by the genitals",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     }
#   ],
#   "38 Ear, nose and throat": [
#     {
#       "criteria": "Unconscious (unresponsive)",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes."
#       ]
#     },
#     {
#       "criteria": "Shortness of breath or difficulty breathing",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing.\n\nIf the person can’t sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards.\n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change."
#       ]
#     },
#     {
#       "criteria": "Major bleeding from the nose or throat. Pale, clammy skin (cold sweating)",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nDIFFICULT TO WAKE, DROWSY, SLEEPY (altered level of consciousness)\n- Lay the person on his / her side.\n- Make sure the airway is free.\n- Keep warm with blankets (or clothing) over and under the person, and keep the person in a sheltered area.",
#         "\nNOSEBLEED\n- Sit with the head tilted forwards.\n- Pinch the soft part of the nose for 20 mins.\n- Rinse out the mouth with plenty of cold water.\n- Do not blow the nose or swallow the blood.\n- Seek medical advice if it continues."
#       ]
#     },
#     {
#       "criteria": "Swallowed a button battery",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing.\n\nIf the person can’t sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards.\n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change."
#       ]
#     },
#     {
#       "criteria": "Possible fever, difficulty swallowing",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing.\n\nIf the person can’t sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards.\n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change."
#       ]
#     },
#     {
#       "criteria": "Bleeding after a throat operation",
#       "advices": [
#         "\nIMPORTANT INFORMATION TO THE CALLER\n- Help is on the way. I may need to phone you back, so keep this phone free until the medics arrive.\n- Watch the person all the time. Tell me immediately if anything changes.",
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times.",
#         "\nPOST-OPERATIVE BLEEDING\n- Get the person to sit up.\n- The person must avoid swallowing blood, it will make him/her nauseous.\nOBS! Lav terskel for kontakt med ØNH lege"
#       ]
#     },
#     {
#       "criteria": "Child persistently coughing, generally unwell",
#       "advices": [
#         "\nCOUGH AND DIFFICULTY BREATHING\n- Help the person find a comfortable position, sitting or lying with the upper body elevated. This reduces swelling in the mucous membranes and may help."
#       ]
#     },
#     {
#       "criteria": "Very sore throat, generally unwell",
#       "advices": [
#         "\nCOUGH AND DIFFICULTY BREATHING\n- Help the person find a comfortable position, sitting or lying with the upper body elevated. This reduces swelling in the mucous membranes and may help."
#       ]
#     },
#     {
#       "criteria": "Obstruction in the throat, breathing normally",
#       "advices": [
#         "\nDIFFICULTY BREATHING\n- Try to create calm around the person, loosen tight clothing.\n- Help the person to sit up / find a comfortable position.\n- Observe breathing.\n\nIf the person can’t sit up:\n- Lay the person on one side.\n- Gently tilt the head back and lift the chin forwards.\n\nInfant under 1 year:\n- Keep the head in a neutral position and lift the chin forwards.\n- Observe breathing, tell me if there is any change.",
#         "\nCOUGH AND DIFFICULTY BREATHING\n- Help the person find a comfortable position, sitting or lying with the upper body elevated. This reduces swelling in the mucous membranes and may help."
#       ]
#     },
#     {
#       "criteria": "Major nosebleed, lasting more than 20 minutes",
#       "advices": [
#         "\nNOSEBLEED\n- Sit with the head tilted forwards.\n- Pinch the soft part of the nose for 20 mins.\n- Rinse out the mouth with plenty of cold water.\n- Do not blow the nose or swallow the blood.\n- Seek medical advice if it continues."
#       ]
#     },
#     {
#       "criteria": "Suddenly dizzy and unwell, stroke or TIA not suspected",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times."
#       ]
#     },
#     {
#       "criteria": "Sudden reduced hearing and dizzy without any clear reason",
#       "advices": [
#         "\nMEDICATION\n- Any medication being used by the person must accompany them at all times."
#       ]
#     },
#     {
#       "criteria": "Post-operative bleeding in the throat, bleeding has stopped",
#       "advices": [
#         "\nPOST-OPERATIVE BLEEDING\n- Get the person to sit up.\n- The person must avoid swallowing blood, it will make him/her nauseous.\nOBS! Lav terskel for kontakt med ØNH lege"
#       ]
#     },
#     {
#       "criteria": "Pain over the cheeks, forehead or eyes. Worsens when bending forwards",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Possible broken nose",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Cold, sore throat or cough, seems fine otherwise",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Earache",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Discharge from the ear, has an ear infection",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Has a foreign object in the ear canal",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Has a foreign object in the nose",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Nosebleed lasting less than 20 minutes",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Dizzy spells",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     },
#     {
#       "criteria": "Toothache",
#       "advices": [
#         "\nConsult the emergency primary care index (LVI).\n- https://legevaktindeks.no/"
#       ]
#     }
#   ]
# }

# %%
import itertools
from langchain_community.vectorstores import FAISS
from langchain.schema import Document
from langchain.embeddings import init_embeddings
embed_model = init_embeddings("ollama:nomic-embed-text:latest")


def clean_chapter(text):
	# text = text.replace("/", ",")
	text = re.sub(r'#', '', text) # Remove hashtags
	text = re.sub(r'\d+', '', text)  # Remove numbers
	return text.strip()



#docs_summary = []

docs_criteria_advices = []
compiled_criteria = []
docs_criteria = []
docs_chapter = []


for i, (chapter, criteria_list) in enumerate(criteria_chapter_map.items()):

	content = ChapterContent[chapter]
	data_list = criteria_advice_mapping[chapter]
	advices_list = list(set(list(itertools.chain.from_iterable([entry["advices"] for entry in data_list]))))
	

	# full document embedding
	embed_str_doc = "search_document:\n" + content.replace("\n\n", "\n")
	docs_chapter.append(
		Document(page_content=embed_str_doc, metadata={"chapter": chapter})
	)

	# criteria and advices embedding
	criteria_advice_str = f'search_document:\nCHAPTER: "{clean_chapter(chapter)}"\n\nCRITERIA:\n\n' + format_text(criteria_list) + "\n\nADVICES:\n" + "\n\n- ".join(advices_list)
	criteria_advice_str = "\n".join(
		line for line in criteria_advice_str.splitlines()
		if not (line.strip().startswith("-") and line.strip() == "-")
	)
	docs_criteria_advices.append(
		Document(page_content=criteria_advice_str, metadata={"chapter": chapter})
	)
	

	# compiled criteria embedding
	compiled_criteria_str = f'search_document:\nCHAPTER: "{clean_chapter(chapter)}"\n\nCRITERIA:\n' + format_text(criteria_list)
	compiled_criteria.append(
		Document(page_content=compiled_criteria_str, metadata={"chapter": chapter})
	)
	

	# criteria embedding
	criteria_str = f'search_document:\nChapter: "{clean_chapter(chapter)}"\n\nCriteria:\n- ' + "\n- ".join(criteria_list)
	docs_criteria.append(
		Document(page_content=criteria_str, metadata={"chapter": chapter})
	)

	# print(embed_str_summary)

	# print(embed_str_doc)
	#print("==========================")


# vectorstore_criteria = FAISS.from_documents(docs_summary, embed_model)
# vectorstore_criteria.save_local("VectorStores/Summary_Chapter_FAISS")

# vectorstore_criteria = FAISS.from_documents(docs_chapter, embed_model)
# vectorstore_criteria.save_local("VectorStores/Summary_Criteria_Chapter_FAISS")

# with open("Chapter_Criteria.jsonl", "w", encoding="utf-8") as f_out:
# 	for chapter, criteria in save_test.items():
# 		entry = {
# 			"chapter": chapter,
# 			"criteria": criteria
# 		}
# 		f_out.write(
# 			json.dumps(entry, ensure_ascii=False) + "\n"
# 		)


FAISS.from_documents(docs_chapter, embed_model).save_local("VectorStores2/Chapter_FAISS")
FAISS.from_documents(docs_criteria_advices, embed_model).save_local("VectorStores2/Criteria_Advices_FAISS")
FAISS.from_documents(docs_criteria, embed_model).save_local("VectorStores2/Criteria_FAISS")
FAISS.from_documents(compiled_criteria, embed_model).save_local("VectorStores2/Compiled_Criteria_FAISS")

# %%
from langchain_community.vectorstores import FAISS
from langchain.embeddings import init_embeddings
embed_model = init_embeddings("ollama:nomic-embed-text:latest")
criteria_vectorstore = FAISS.load_local(folder_path="VectorStores/Criteria_Chapter_FAISS", embeddings=embed_model, allow_dangerous_deserialization=True)
summary_criteria_vectorstore = FAISS.load_local(folder_path="VectorStores/Summary_Criteria_Chapter_FAISS", embeddings=embed_model, allow_dangerous_deserialization=True)
summary_vectorstore = FAISS.load_local(folder_path="VectorStores/Summary_Chapter_FAISS", embeddings=embed_model, allow_dangerous_deserialization=True)

def get_chapter_vectorstore(query, top_k=6):
    prefix = "search_query: "
    query = prefix + query
    ntotal = summary_criteria_vectorstore.index.ntotal

    def get_rank(query, k):
        summary_results = summary_criteria_vectorstore.similarity_search(query, k=k)
        seen_chapters = set()
        rank = []
        for res in summary_results:
            chapter = res.metadata.get("chapter")
            if chapter not in seen_chapters:
                seen_chapters.add(chapter)
                rank.append(chapter)
        return rank

    if top_k >= ntotal:
        return get_rank(query, k=ntotal)

    for k in range(top_k, ntotal):
        rank = get_rank(query, k=k)
        if len(rank) >= top_k:
            return rank

    # Fallback if unique chapters never reach top_k
    return get_rank(query, k=ntotal)


def get_criteria_vectorstore(query, top_k=6):
	prefix = "search_query: "
	criteria_results = criteria_vectorstore.similarity_search(prefix + query, k=top_k)
	response = []
	for res in criteria_results: 
		chap = res.metadata.get("chapter")
		response.append({"content": res.page_content, "chapter": chap})
	return response

def get_summary_vectorstore(query, top_k=6):
	prefix = "search_query: "
	criteria_results = summary_vectorstore.similarity_search(prefix + query, k=top_k)
	response = []
	for res in criteria_results: 
		chap = res.metadata.get("chapter")
		response.append({"content": res.page_content, "chapter": chap})
	return response

# %%
semantic_prompt_template = PromptTemplate(
    template="""
You are an assistant for a medical triage system. Identify the 5 most relevant medical chapters based on the user query. Each chapter has a numeric ID and a summary.

## Chapter Summaries:
{chapter_summaries}

## User Query:
{query}

# Instructions:
- Only select from the provided chapters.
- Do not hallucinate or invent any chapter names.
- Return exactly 5 chapter IDs in descending order of relevance.

# Output Format (example):
```json
{{
  "retrieved": [5,2,3,1,4]
}}
```
""",
    input_variables=["query", "chapter_summaries"]
)



def get_criteria_vectorstore(query, top_k=6):
	prefix = "search_query: "
	criteria_results = criteria_vectorstore.similarity_search(prefix + query, k=top_k)
	response = []
	for res in criteria_results: 
		chap = res.metadata.get("chapter")
		response.append({"content": res.page_content, "chapter": chap})
	return response

# %%
query =  {
	"condition": "Unconscious, not breathing normally, difficulty breathing",
	"observations": "Complaining about feeling ill for a couple of days",
	"cause": "Unknown medical condition",
	"callers_actions": "Helping patient"
}
query = json.dumps(query, indent=2, ensure_ascii=False)
retrieval = get_criteria_vectorstore(query, top_k=15)
rag_candidates = [result["chapter"].lower() for result in retrieval]
display("🔐 Retrieved Candidate Chapters (Criteria):",rag_candidates)

# %%
summary =  {
	"condition": "conscious, not breathing normally, difficulty breathing",
	"observations": "fire and Burning injuries",
	"cause": "Unknown medical condition",
}


summary = json.dumps(summary, indent=2, ensure_ascii=False)
retrieval = get_summary_vectorstore(summary, top_k=10)
candidates = [result["chapter"] for result in retrieval]
display("🔐 Retrieved Candidate Chapters (Summary of Criteria):",candidates)
print("-"*50)
retrieval = get_chapter_vectorstore(summary, top_k=5)
display("🔐 Retrieved Candidate Chapters (Summary + Criteria):",retrieval)
print("-"*50)
retrieval = get_criteria_vectorstore(summary, top_k=5)
candidates = [result["chapter"] for result in retrieval]
display("🔐 Retrieved Candidate Chapters (Criteria):",candidates)
print("-"*50)
# Out:
# '🔐 Retrieved Candidate Chapters (Summary of Criteria):'
# ['36 Uncertain / unidentified problem',
#  '22 Fever / infection / sepsis',
#  '33 Breathing problems',
#  '12 Major incident',
#  '10 Chemicals / gasses / CBRN',
#  '08 Drowning',
#  '30 Hyperthermia / heat stroke / heat exhaustion',
#  '04 Choking / foreign object',
#  '16 Child / infant - illness',
#  '11 Accident / injury']
# --------------------------------------------------
# '🔐 Retrieved Candidate Chapters (Summary + Criteria):'
# ['07 Burns',
#  '11 Accident / injury',
#  '33 Breathing problems',
#  '10 Chemicals / gasses / CBRN',
#  '03 Unconscious / decreased level of consciousness, breathing normally']
# --------------------------------------------------
# '🔐 Retrieved Candidate Chapters (Criteria):'
# ['07 Burns',
#  '33 Breathing problems',
#  '11 Accident / injury',
#  '36 Uncertain / unidentified problem',
#  '22 Fever / infection / sepsis']
# --------------------------------------------------
